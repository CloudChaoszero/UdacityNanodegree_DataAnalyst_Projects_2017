# %% [markdown]
# # Data Wrangling OSM: San Francisco Edition

# %% [markdown]
# **San Franciso, Ca**
#
# We will observe San Francisco, Ca region in [OpenStreetMap.org](https://www.openstreetmap.org) and use data munging techniques, such as assessing the quality of the data for validity, accuracy, completeness, consistency and uniformity, to clean the selected OpenStreetMap data.
#
# ![San Francisco, CA](Images/BayBridge.jpg)
#
#
# **Why we select the San Francisco Region**
#
# [San Francisco, Ca](https://www.openstreetmap.org/search?query=san%20francisco#map=12/37.7444/-122.4382) is the current city I reside in. My motivations for using San Francisco in this data wrangling procedure is to both show that I exist, and indicate I am a proficient analyst looking to grow with an excellent organization.
#
# Below is an image of the [Salesforce Tower](http://www.salesforcetower.com/). This tower represents the heights I want to reach to. Though with time and proper construction, I will stand tall in this city.
#
# ![Salesforce Tower](Images/sf_tower.jpg)
#
# **Project Outcomes:**
#
# - Assess the quality of the data for validity, accuracy, completeness, consistency and uniformity.
# - Parse and gather data from popular file formats such as .csv, .json, .xml, and .html
# - Process data from multiple files or very large files that can be cleaned programmatically.
# - Learn how to store, query, and aggregate data using MongoDB or SQL.
#
#
#
#
# **Notes: **
# - I will be using SQL as my data schema for this project.
# - Documentation of OpenStreetMap XLM data can be found [here](https://wiki.openstreetmap.org/wiki/OSM_XML)

# %% [markdown]
# #### CLICK HERE TO TOGGLE ON/OFF CODE
# &darr; &darr; &darr; &darr;  &darr; &darr; &darr; &darr;  &darr; &darr; &darr; &darr;  &darr; &darr; &darr; &darr;  &darr; &darr; &darr; &darr;

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Import

# %%
#Import Libraries

###XML library ElementTree
import xml.etree.cElementTree as ET

###Print
import pprint

###Regular expression
import re

###CSV and Dictionary 
from collections import defaultdict
import csv
import codecs

###Data validation
import cerberus
import validators
import phonenumbers

##3Schema format
import schema_guidline
import schema

###Maths and data 
import numpy as np

###String
import string
import schema_guidline

#SQL 
import sqlite3

# %%
OSM_FILE = "C:/Users/rmald_000/Downloads/Udacity-DataAnalyst-Downloads/Large-Files/P3/san-francisco_california.osm"
SAMPLE_FILE = "san-francisco_california_sample.osm"

# %%
'''
Function: get_elements_sample takes in parameters osm_file and tags.
This function gets a specified element from an osm file

The with statement as output is the procedure of getting every 100th element fromt the main osm file
'''


k = 100 # Parameter: take every k-th top level element

def get_elements_sample(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write(bytes('<?xml version="1.0" encoding="UTF-8"?>\n', 'UTF-8'))
    output.write(bytes('<osm>\n  ', 'UTF-8'))

    # Write every 10th top level element
    for i, element in enumerate(get_elements_sample(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write(bytes('</osm>', 'UTF-8'))

# %% [markdown]
# We first import several libraries. The most important of these libraries is the [Element Tree library](https://docs.python.org/2/library/xml.etree.elementtree.html).
#
# We then recognize two local OSM files; We recognize the San Francisco(SF) OSM file and the subset file to the SF OSM file. The subset file is where we will fill every 1000 element of the main SF file to the subset SF file
#
# Thereafter, we proceed with obtaining every 100th k element from the main SF OSM file

# %%
sf = SAMPLE_FILE

# %%
#Get San Francisco Tree
tree = ET.parse(sf)

# %%
#Get root of 'tree'
root = tree.getroot()

# %%
#Check the tags for each element
####Release 'break' to see full list of top level tags
for event, element in ET.iterparse(sf, events=("start",)):
    print("OSM Tag:")
    print(element.tag)
    break
# Out:
# OSM Tag:
# osm

# %% [markdown]
# We parse the subset SF file (sf) to get the root of this osm file.
#
# We then confirm the procedure worked by printing out the OSM Tag.

# %% [markdown]
# ## Defining Node Tags

# %%
'''
Function count_tags counts the number of top, parent, and child tags
parameter: OSM File
'''
def count_tags(filename):
    tree = ET.parse(filename)
    root = tree.getroot()
    
    tag_count = {}
    
    #Get count of all tags. If no tag is in there, add to dictionary with
    ##Count as 1
    for event, element in ET.iterparse(filename,events=("start",)):
        element_tag = element.tag
        if element_tag not in tag_count:
            tag_count[element_tag] = 1
        else:
            tag_count[element_tag] += 1
            
    return(tag_count)

# %%
#Implement count_tags function
count_of_tags = count_tags(sf)

print("Number of tags:\n",count_of_tags)
# Out:
# Number of tags:
#  {'member': 452, 'way': 8110, 'osm': 1, 'node': 65712, 'nd': 76351, 'relation': 62, 'tag': 19888}

# %% [markdown]
# We obtain a dictionary of tags and their respective counts. However, what are these tags?
#
# The following is a brief definition of the element and tag meanings in our dataset

# %% [markdown]
# **Element and Tag meanings:**
#
# nd:
#
# bounds: Boundary
#
# member:
#
# way: defining linear features and area boundaries
#
# osm: OpenStreetMap
#
# node: defining points in space
#
# tag: defining specific features of map elements
#
# relation:  explain how other elements work together

# %% [markdown]
# ## Tag Types and Potential Issues

# %% [markdown]
# ### Tag Types

# %%
#Regular expresion lists for lower, lower_colon, and problem characters

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %%
#Function key_type that has parameters element and key
##returns key
####Counts the element keys in tree if they are part of the three previously mentioned regular expression categories
def key_type(element,key):
    if element.tag =="tag":
        for tag in element.iter("tag"):
            attrib_k = tag.attrib["k"]
            if re.search(lower,attrib_k):
                key["lower"] +=1
            elif re.search(lower_colon,attrib_k):
                key["lower_colon"] +=1
            
            elif re.search(problemchars,attrib_k):
                key["problemchars"] +=1
                
            else:
                key["other"] += 1
    return(key)

# %%
#Process map function that takes in OSM file
###Categorize element keys and place them in dictionary
def process_map(filename):
    keys = {"lower":0,"lower_colon":0,"problemchars":0,"other":0}
    #Implement key_type function for reach element's key
    for event, element in ET.iterparse(filename):
        keys = key_type(element,keys)
    return(keys)

# %%
map_processed = process_map(sf)

# %%
pprint.pprint(map_processed)
# Out:
# {'lower': 14007, 'lower_colon': 5700, 'other': 178, 'problemchars': 3}

# %% [markdown]
# ### Tag issues
#
# We observe 3 tag issues, as seen in the above dictionary. problemchars is 3.
#
# Should we consider looking into 'other' tags? No because the `other` tag is a tag, and not a warning to the user about the tag type.

# %% [markdown]
# ## Find Users

# %%
#Find user function that takes in OSM file
###Return a set and list of OSM contributors, where set is the unique list
def find_users(filename):
    users_set = set()
    users_list = []
    element_osm = ["node","way","relation"]
    for event, element in ET.iterparse(filename):
        if element.tag == "node" or element.tag == "way" or element.tag=="relation":
            for osm_el in element_osm:
                for el in element.iter(osm_el):
                    user_id = el.attrib["uid"]
                    
                    users_list.append(user_id)
                    if user_id not in users_set:
                        users_set.add(user_id)
                    else:
                        pass
    return(users_set,users_list)

# %%
user_search = find_users(sf)

#Get set of OSM contributors
print(user_search[0])
# Out:
# {'1185712', '2035254', '2967601', '1860668', '4225299', '3916314', '25510', '1214881', '5007769', '94578', '290680', '2115749', '4902', '160138', '5359', '106828', '338351', '3125856', '4845203', '1494110', '3817650', '360392', '652230', '2318', '2560523', '2763448', '171119', '123633', '432824', '58305', '1403907', '3793530', '4325299', '2219338', '1836535', '45611', '5239832', '320343', '1861330', '53936', '1835512', '1731525', '2880297', '4148813', '416346', '169004', '2985232', '33757', '120468', '3282935', '322404', '190493', '665694', '3151684', '46220', '1546527', '2012966', '1556219', '2209894', '2819599', '72002', '28145', '383461', '25604', '60612', '174586', '119881', '3483725', '5475233', '3478684', '2332032', '2052349', '4518035', '81497', '2747838', '2229097', '3569951', '2512300', '21931', '2601744', '4893098', '2137840', '2240804', '5400451', '6585', '3215437', '567792', '8287', '4899678', '1745338', '606225', '5367179', '3696217', '2306749', '4115', '5667998', '2688775', '2886207', '214969', '4460614', '138911', '3526564', '3769434', '2593828', '6367', '100744', '190869', '398300', '3601534', '330773', '257555', '338843', '3095', '485507', '3397838', '107257', '2257567', '1260280', '828519', '199600', '100467', '950182', '1110270', '2773196', '83557', '5448688', '103253', '3272286', '2086526', '706170', '2655992', '37067', '3696204', '2393795', '411298', '38784', '3528573', '1597155', '3389275', '1758880', '5210438', '521541', '1212745', '381253', '3415463', '341519', '2176692', '2639622', '25867', '3696207', '573196', '550560', '1980320', '27781', '2724074', '1733620', '4288424', '1711265', '4386661', '162110', '2050600', '1282393', '4892902', '37137', '24555', '1775756', '130277', '5133699', '1529343', '14179', '1722904', '2682147', '500006', '1708763', '55774', '242352', '355242', '1535346', '23762', '2848193', '2015224', '2323512', '105946', '25996', '40397', '564585', '48060', '941449', '1829683', '2554698', '88961', '593205', '11154', '618377', '1355899', '1249504', '3397796', '305985', '4213591', '3397814', '4510966', '1249130', '4884078', '2032360', '4543547', '291298', '6975', '93800', '35935', '163803', '589596', '12671', '3696230', '429728', '682', '1213894', '2136684', '2508151', '703517', '1797586', '1210008', '2944689', '29017', '475877', '1883329', '3397846', '5222544', '36121', '2953895', '455164', '74705', '35195', '296793', '305001', '1240849', '2038932', '194231', '31231', '595221', '2100843', '1297360', '103340', '4503285', '3905761', '3521724', '1917271', '8909', '7168', '2580175', '1893220', '104461', '1083211', '290016', '2876693', '4314582', '371711', '665748', '3346582', '4742311', '202256', '1850735', '70092', '192581', '529836', '2370549', '5187925', '2240409', '1751737', '158274', '3178375', '73268', '2886662', '1660455', '3415446', '321578', '148800', '711243', '982633', '81024', '2328400', '2412184', '93285', '945595', '2697733', '5183376', '4896980', '4893041', '123364', '2847988', '1323941', '160949', '2049447', '25663', '401490', '1529919', '135163', '361207', '837425', '1247632', '3029661', '5853065', '532783', '206785', '13192', '829302', '116029', '2883452', '70696', '2764994', '3558911', '125457', '93788', '2946756', '136211', '597941', '349023', '2422893', '1980326', '1018369', '3624816', '297064', '6106546', '4967074', '3057995', '2061773', '1376118', '210173', '588517', '1408707', '2045423', '352170', '207745', '670691', '56597', '47892', '347787', '120160', '5184971', '4928324', '1586627', '626299', '583866', '2177', '231723', '3397844', '236172', '24452', '42429', '22946', '35254', '3696439', '109968', '4681914', '74275', '5236034', '2033336', '4109236', '235835', '88771', '190690', '479256', '303224', '3397534', '4801391', '2406578', '1577172', '3049198', '85177', '450292', '2925215', '81909', '201724', '4353543', '144449', '5185806', '1796809', '35372', '4651319', '178186', '533465', '5733618', '1211007', '4732', '1778256', '3260615', '3990', '2441939', '363927', '12 ...

# %% [markdown]
# We have the unique set of users in this sample of San Francisco, Ca data. However, we want to know the contribution rate of some user, and what the top contributor is?
#
#
# Below is a function for computing the stats of top contributors

# %%
#user_stats function takes in a list of users(user_search[1])
###outputs total contribution, contribution rate, mean, mean of contribution rate
### standard deviation, and standard deviation of rate of contributions, in order.
def user_stats(user_list):
    #Make set of users
    users_unique = set(user_list)
    #Dictionary count
    user_contribution_count = {}
    #Count of contributions
    total_contributions = 0
    stdev = None
    
    contribution_rate = {}
    
    #Calculate count per user
    for user in user_list:
        if user not in user_contribution_count:
            user_contribution_count[user] = 1
        else:
            user_contribution_count[user] +=1
    #calculate total count        
    for key, value in user_contribution_count.items():
        total_contributions +=value
    #Contribution rate     
    for key, value in user_contribution_count.items():
        contribution_rate[key] = value / total_contributions
    #Get mean of contributions and rate of contributions    
    mean_val = np.mean(list(user_contribution_count.values() ) )
    mean_val_rate = np.mean(list(contribution_rate.values() ) )
    
    #Get std.dev of contributions and rate of contributions 
    stdev_val = np.std(list(user_contribution_count.values() ) )
    stdev_val_rate =  np.std(list(contribution_rate.values() ) )
    
    return(total_contributions,contribution_rate,mean_val,mean_val_rate ,stdev_val,stdev_val_rate)

# %%
user_statistics = user_stats(user_search[1])

# %%
#Contribution rate
print("Contribution rate")
print(user_statistics[1])
# Out:
# Contribution rate
# {'1185712': 5.413892046992583e-05, '2035254': 1.3534730117481457e-05, '1860668': 1.3534730117481457e-05, '4225299': 5.413892046992583e-05, '3916314': 1.3534730117481457e-05, '25510': 0.0008391532672838504, '3397534': 1.3534730117481457e-05, '5007769': 1.3534730117481457e-05, '94578': 0.2029262086513995, '290680': 6.767365058740728e-05, '2115749': 0.0038573980834822152, '4902': 1.3534730117481457e-05, '160138': 0.012668507389962644, '5359': 0.0002571598722321477, '106828': 0.00016241676140977748, '3125856': 1.3534730117481457e-05, '4845203': 0.006266580044393915, '3817650': 8.120838070488874e-05, '360392': 1.3534730117481457e-05, '652230': 1.3534730117481457e-05, '2318': 0.001272264631043257, '2560523': 2.7069460234962914e-05, '171119': 1.3534730117481457e-05, '123633': 0.0005278544745817769, '432824': 2.7069460234962914e-05, '58305': 1.3534730117481457e-05, '1403907': 2.7069460234962914e-05, '3793530': 1.3534730117481457e-05, '2219338': 0.054856261166152345, '1836535': 8.120838070488874e-05, '1861330': 1.3534730117481457e-05, '53936': 1.3534730117481457e-05, '2967601': 1.3534730117481457e-05, '1835512': 0.0001894862216447404, '1731525': 1.3534730117481457e-05, '2880297': 1.3534730117481457e-05, '4148813': 2.7069460234962914e-05, '416346': 0.0005278544745817769, '169004': 0.022345839423961886, '2985232': 0.0004466460938768881, '33757': 0.00013534730117481457, '120468': 0.0006632017757565914, '3282935': 1.3534730117481457e-05, '322404': 4.060419035244437e-05, '190493': 0.00024362514211466623, '665694': 4.060419035244437e-05, '2209894': 0.00012181257105733311, '46220': 4.060419035244437e-05, '2012966': 1.3534730117481457e-05, '1214881': 0.00014888203129229604, '2819599': 2.7069460234962914e-05, '158274': 6.767365058740728e-05, '72002': 6.767365058740728e-05, '28145': 6.767365058740728e-05, '383461': 0.000798549076931406, '2411': 6.767365058740728e-05, '25604': 0.0009068269178712576, '60612': 5.413892046992583e-05, '174586': 1.3534730117481457e-05, '119881': 0.0006496670456391099, '3483725': 0.0001894862216447404, '5475233': 1.3534730117481457e-05, '3478684': 4.060419035244437e-05, '2332032': 1.3534730117481457e-05, '4518035': 4.060419035244437e-05, '81497': 0.0002571598722321477, '2747838': 0.00010827784093985166, '3569951': 2.7069460234962914e-05, '2512300': 0.017216176709436416, '21931': 4.060419035244437e-05, '2137840': 1.3534730117481457e-05, '4893098': 0.003667911861837475, '2240804': 2.7069460234962914e-05, '6144079': 1.3534730117481457e-05, '5400451': 1.3534730117481457e-05, '6585': 6.767365058740728e-05, '3215437': 1.3534730117481457e-05, '1247632': 0.00014888203129229604, '933797': 0.011748145741973906, '567792': 0.0006090628552866656, '4899678': 5.413892046992583e-05, '1745338': 0.00012181257105733311, '606225': 1.3534730117481457e-05, '950182': 1.3534730117481457e-05, '5367179': 2.7069460234962914e-05, '3696217': 1.3534730117481457e-05, '2306749': 1.3534730117481457e-05, '4115': 1.3534730117481457e-05, '5667998': 1.3534730117481457e-05, '2688775': 1.3534730117481457e-05, '135329': 1.3534730117481457e-05, '2886207': 5.413892046992583e-05, '214969': 0.00016241676140977748, '138911': 2.7069460234962914e-05, '3526564': 0.00027069460234962914, '3769434': 5.413892046992583e-05, '2593828': 1.3534730117481457e-05, '6367': 1.3534730117481457e-05, '190869': 1.3534730117481457e-05, '398300': 2.7069460234962914e-05, '4732': 8.120838070488874e-05, '3601534': 1.3534730117481457e-05, '330773': 0.00014888203129229604, '74228': 1.3534730117481457e-05, '257555': 1.3534730117481457e-05, '338843': 1.3534730117481457e-05, '3095': 0.00012181257105733311, '485507': 1.3534730117481457e-05, '3397838': 1.3534730117481457e-05, '2257567': 5.413892046992583e-05, '1260280': 1.3534730117481457e-05, '338351': 1.3534730117481457e-05, '828519': 1.3534730117481457e-05, '199600': 0.00013534730117481457, '100467': 1.3534730117481457e-05, '1110270': 0.00010827784093985166, '83557': 2.7069460234962914e-05, '5448688': 0.00013534730117481457, '103253': 0.0001 ...

# %%
max_user = None
max_user_value = 0
for key,value in user_statistics[1].items():
    if value >max_user_value:
        max_user_value = value
        max_user = key
print("Most contributions from User:",max_user,"\nwith a total contribution rate of:",max_user_value)
# Out:
# Most contributions from User: 94578
# with a total contribution rate of: 0.2029262086513995

# %%
#Average number of contributions
print("Average number of Contributions")
print(user_statistics[2],"\n")

#Total count of contributions
print("Total count of Contributions")
print(user_statistics[0],"\n")

#average rate of contributions
print("Average rate of Contributions")
print(user_statistics[3],"\n")

#Stdev of number of contributions
print("Standard deviation of Contributions")
print(user_statistics[4],"\n")

#Stdev of rate of contributions
print("Standard deviation of the rate of Contributions")
print(user_statistics[5],"\n")
# Out:
# Average number of Contributions
# 95.5808538163
#
# Total count of Contributions
# 73884
#
# Average rate of Contributions
# 0.0012936610608
#
# Standard deviation of Contributions
# 738.607732077
#
# Standard deviation of the rate of Contributions
# 0.00999685631635

# %% [markdown]
# ## Auditing Data

# %% [markdown]
# We determine the integrity of our data. We look into the street key and values entries to determine if they are correctly entered.

# %%
#Regular expression for street type for ignoring b,repitition of S, and some other character with 0 or 1 repititions

street_type_re = re.compile(r'St\.|St{2,}|Rd|Rd.|Ave{3,}', re.IGNORECASE)
#Expected street spelling list
expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]
#Map street abbr. to actual word
mapping = { "St": "Street",
            "St.": "Street", "Ave":"Avenue","Rd":"Road"
            }

mapping_abbrev = { 'W ': 'West ', 'S ': 'South ', 'N ': 'North ', 'E ': 'East ',
                   'W. ': 'West ', 'S. ': 'South', 'N. ': 'North ', 'E. ': 'East '
                 }
mapping_zipcodes = ['95356','95307','95358']

# %%
#Create audit_street_type function with parameters street_types,street_name
## to obtain mispelled streets
def audit_street_type(street_types,street_name):
    street_name = street_name.strip("{")
    street_name = street_name.strip("}")
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type] = (street_name)
            
#Audit state type
state_types = []
def audit_state_type(state_types,state):
    if len(state) !=2:
        state_types.append(state)
        
zipcode_types = []
def audit_zipcode_type(zipcode_types,zipcode):
    if len(zipcode) != 5:
        zipcode_types.append(zipcode)
        
housenumber_type_re = re.compile(r'^\d+(-?\d)*$')

housephone_number_types = []

#Audit housephone values
def audit_housephone(housephone_number_types, number):
    m = housenumber_type_re.search(number)
    if not m:
        housephone_number_types.append(number)

phone_number_types = []

#Audit phone entires. We use phonenumbers library to verify #'s
def audit_phone(phone_number_types,number):
    if number.startswith("+"):
        number = number[1:]
    z = phonenumbers.parse(number,"US")
    v = phonenumbers.is_possible_number(z)
    if not v:
        phone_number_types.append(number)
#Audit website values. We use validators to confirm url entry
website_types = []
def audit_website(website_types,website):
    if not website.startswith('http'):
        website = 'http://' + website
    if not validators.url(website):
        website_types.append(website)

# %%
#identify street in element's key
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def is_street_name(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street")

def is_state(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:state" or elem.attrib['k'] == "is_in:state_code")

def is_postcode(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:postcode")

def is_housenumber(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:housenumber")

def is_phone(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == 'phone')

def is_website(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "website" or elem.attrib['k'] == "url" or \
                                    (elem.attrib['k'] == "source" and elem.attrib['v'].startswith("http")))

# %%
def printer(type_of):
    pprint.pprint(type_of)

#audit function that takes in osm file
def audit(osmfile):
    #Read in osmfile
    osm_file = open(osmfile,'r',encoding="utf-8")
    #Create empty defaultdict 
    street_types = defaultdict(set)
    
    #go through each element in osm file. If it is a node or a tag, and has child tags, then
    ##we audit the street type and tag attribute v
    for event, element in ET.iterparse(osm_file,events =("start",) ):
        if element.tag == "node" or element.tag=="way":
            for tag in element.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return(street_types)


#Additional audits for several variables, all in one. 
def audit_additional(file):
    for event, elem in ET.iterparse(file):
        if is_state(elem):
            audit_state_type(state_types, elem.attrib['v'])
        elif is_postcode(elem):
            audit_zipcode_type(zipcode_types, elem.attrib['v'])
        elif is_housenumber(elem):
            audit_housephone(housephone_number_types, elem.attrib['v'])
        elif is_phone(elem):
            audit_phone(phone_number_types, elem.attrib['v'])
        elif is_website(elem):
            audit_website(website_types, elem.attrib['v'])

# %%
#Function update_name that has parameters name and mapping
def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        #If the name exist in mapping keys, it means that's a problem and we should fix it.
        if street_type in mapping.keys():
            name = re.sub(street_type, mapping[street_type], name)
    return(name)

def update_state(state, state_list):
    if state in state_list:
        state = "CA"
    return(state)


#postcode_type_re = re.compile(r'[0-9]+')
def update_postcode(postcode_types):
    if type(postcode_types) is type([]):
        pc_list = []
        for postcode in postcode_types:
            pc_list.append(postcode.split(" ")[1])

            return(pc_list)
    elif type(postcode_types) is type(''):
        if len(postcode_types) !=5:
            postcode = postcode_types.split(" ")
            return(postcode[1])

# %%
st_types = audit(sf)
print(st_types)
# Out:
# defaultdict(<class 'set'>, {'rd': '3rd Street'})

# %%
dict_st_stypes = dict(st_types)
print(dict_st_stypes)
# Out:
# {'rd': '3rd Street'}

# %%
#For every way in st_types
for st_type, ways in st_types.items():
    #For every name in way
    print(ways)
    better_name = update_name(ways, mapping)
# Out:
# 3rd Street

# %%
better_name
# Out:
# '3rd Street'

# %%
st_types_set = dict(st_types)
for event, element in ET.iterparse(sf, events=("start",)):
    for tag in element.iter("tag"):
        if(tag.attrib['k']=="addr:street"):
            for key, val in st_types.items():
                if tag.attrib['v'] == val:
                    print(tag.attrib['v'])
                    tag.attrib['v'] = better_name
                    print("Turned into")
                    print(tag.attrib['v'])
# Out:
# 3rd Street
# Turned into
# 3rd Street
# 3rd Street
# Turned into
# 3rd Street
# 3rd Street
# Turned into
# 3rd Street
# 3rd Street
# Turned into
# 3rd Street

# %% [markdown]
# The above code lists 4 values of "3rd Street" updated to some new value. However, it's still the same.
#
# We need to see the condition on how this false negative is picked up in our algorithm.
#
# If we look closely, we observe the regular expressions "street_type_re" enabling our algorithm to pick up "3rd Street"

# %%
#Print out the first 10 tags 
##If you want to print out more, take off break portion
i = 0
for event, element in ET.iterparse(sf, events=("start",)):
    #----Break area-----
    i+=1
    if i ==10:
        break
    #----------------
    #Print tag of elements
    for tag in element.iter("tag"):
        print(tag.attrib)
# Out:
# {'k': 'ref', 'v': '35'}
# {'k': 'exit_to', 'v': 'Strobridge Avenue'}
# {'k': 'highway', 'v': 'motorway_junction'}
# {'k': 'source', 'v': 'PGS'}
# {'k': 'source', 'v': 'PGS'}
# {'k': 'ref', 'v': '26'}
# {'k': 'exit_to', 'v': 'Tennyson Road'}
# {'k': 'highway', 'v': 'motorway_junction'}
# {'k': 'created_by', 'v': 'JOSM'}
# {'k': 'created_by', 'v': 'JOSM'}
# {'k': 'barrier', 'v': 'gate'}
# {'k': 'created_by', 'v': 'JOSM'}
# {'k': 'created_by', 'v': 'JOSM'}
# {'k': 'highway', 'v': 'stop'}
# {'k': 'highway', 'v': 'turning_circle'}
# {'k': 'ref', 'v': '35'}
# {'k': 'exit_to', 'v': 'Strobridge Avenue'}
# {'k': 'highway', 'v': 'motorway_junction'}
# {'k': 'ref', 'v': '35'}
# {'k': 'exit_to', 'v': 'Strobridge Avenue'}
# {'k': 'highway', 'v': 'motorway_junction'}

# %%
    print("State Types: ")
    printer(state_types)
    
    print("Zipcode Types: ")
    printer(zipcode_types)
    
    print("Problematic House Numbers: ")
    printer(housephone_number_types)
    
    print("Problematic Phone Numbers: ")
    printer(phone_number_types)
    print("Problematic Website addresses: ")
    printer(website_types)

    
audit_2 = audit_additional(sf)
print(audit_2)
# Out:
# State Types:
# []
# Zipcode Types:
# []
# Problematic House Numbers:
# []
# Problematic Phone Numbers:
# []
# Problematic Website addresses:
# []
# None

# %% [markdown]
# Observing 'v' and 'k' tags within each element, we see that Street Types are not our only concern. I.e., We need to inspect other features in our data to determine data integrity.
#
# We audit for phone, state, zipcode, and website address features in our data.

# %% [markdown]
# We observe there aren't any issues with the additional values. Though this osm file is small, we can anticipate a lower frequency of errors/issues occuring within our data.
#
# **Note:**
#
# In our 50+MB San Francisco, Ca OSM File, we shoul anticipate more errors.
#
# $ $
#
# Again, we observe no incorrect information typed into the Phone Number, Website, and House Number, State values. This is good! We continue to converting our osm data into csv files.

# %% [markdown]
# ## Export to CSV

# %%
NODES_PATH = "CSVFiles/nodes.csv"
NODE_TAGS_PATH = "CSVFiles/nodes_tags.csv"
WAYS_PATH = "CSVFiles/ways.csv"
WAY_NODES_PATH = "CSVFiles/ways_nodes.csv"
WAY_TAGS_PATH = "CSVFiles/ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema_guidline.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %%
state_in_postcode_re = re.compile(r'^([A-Z]){2}\s{1}', re.IGNORECASE)
    #Clean and shape node or way XML element to a dictionary

#shape_element function with parameters:
###element, node_attr_fields,way_attr_fields,problem_chars,default_tag_type
def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""
    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements
    
    #If the top tag is node we then collect the node attributes and tags
    if element.tag == 'node':
        #for every attribute in element
        for attr in element.attrib:
            #and the attribute is in NODE_FIELDS
            if attr in NODE_FIELDS:
                #Collect the attributes into node_attrib dictionary
                node_attribs[attr] = element.attrib[attr]
        #for the child in element        
        for child in element:
            fill_in_dict = {}
            #If any character from the "k" attribute in LOWER_COLON
            if LOWER_COLON.match(child.attrib["k"]):
                #Store values in fill_in_dict
                fill_in_dict["type"] = child.attrib["k"].split(":")[0]
                fill_in_dict["key"] = child.attrib["k"].split(":")[1]
                fill_in_dict["id"] = element.attrib["id"]
                if is_street_name(child):
                    fill_in_dict["value"] = update_name(child.attrib["v"],mapping)
                else:
                    fill_in_dict["value"] = child.attrib["v"]
                tags.append(fill_in_dict)
            #Ignore "k" attribute value if it is a PROBLEMCHARS
            elif PROBLEMCHARS.match(child.attrib["k"]):
                continue
            #If anything else, just save the "k" attribute's values
            else:
                fill_in_dict["type"] =default_tag_type
                if(is_postcode(child)):
                    fill_in_dict['value'] = update_postcode(child.attrib['k'])
                else:
                    fill_in_dict["key"] = child.attrib['k']
                fill_in_dict["id"] = element.attrib['id']
                fill_in_dict["value"] = child.attrib['v']
                tags.append(fill_in_dict)
        return {'node': node_attribs, 'node_tags': tags}
    #If the top element tag is "way"    
    elif element.tag =="way":
        #For every attribute in element
        for attrib in element.attrib:
            #and the attribute is in "WAY_FIELDS"
            if attrib in WAY_FIELDS:
                #Store the attribute in element attribute
                way_attribs[attrib] = element.attrib[attrib]
        #Let position be 0
        position = 0
        
        #For every child in element
        for child in element:
            way_tag = {}
            way_node = {}
            #If the child is a tag
            if child.tag == 'tag':
                
                #If the child attribute "k" matched any item in LOWER_COLON
                if LOWER_COLON.match(child.attrib['k']):
                    #Store the chil attribute values
                    
                    
                    way_tag['type'] = child.attrib['k'].split(':',1)[0] #Get first part of K value
                    way_tag['key'] = child.attrib['k'].split(':',1)[1] #get second part of k value
                    way_tag['id'] = element.attrib['id'] #get id
                    if(is_street_name(child)):
                        way_tag['value'] = update_name(child.attrib['v'],mapping) #get value 'v'
                    else:
                        way_tag['value'] = child.attrib['v'] 
                    tags.append(way_tag) #save way_tag dictiionary
                #Ignore weird "k" values in the child's attribute
                elif PROBLEMCHARS.match(child.attrib['k']):
                    continue
                #If the child's attribute "k" is anything else, just save value
                else:
                    way_tag['type'] = 'regular'
                    if(is_postcode(child)):
                        way_tag['key'] = update_postcode(child.attrib['k'])
                    else:
                         way_tag['key'] = child.attrib['k']
                    way_tag['id'] = element.attrib['id']
                    way_tag['value'] = child.attrib['v']
                    tags.append(way_tag)
            #If the child's tag is "nd", store values
            elif child.tag == 'nd':
                way_node['id'] = element.attrib['id']
                way_node['node_id'] = child.attrib['ref']
                way_node['position'] = position
                position += 1
                way_nodes.append(way_node)
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}

# %%
# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))

# %%
class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)

# %%
# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:
                
        #Write out csv documents
        nodes_writer = csv.DictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = csv.DictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = csv.DictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = csv.DictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = csv.DictWriter(way_tags_file, WAY_TAGS_FIELDS)
        
        #write a header to respective documents
        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()
        
        #data integrity validation
        
        
        
        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
        
            
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    if el['node']['user']=='Юкатан':
                        el['node']['user'] = 'Hokatah'
                    try:
                        nodes_writer.writerow(el['node'])
                    except Exception:
                        print(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    if el['way']['user']=='Юкатан':
                        el['way']['user'] = 'Hokatah'
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])

if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(sf, validate=True)

# %% [markdown]
# <span style= "color:red">The above code has some issues, so I resolved it through data cleaning. mention it in text, hokatah </soan>

# %% [markdown]
# ## Benefit and costs of updating data

# %% [markdown]
# - Tampered with raw data
# - Potentially could have induced bias into our data
# - Typing errors in data cleaning process
# - and more!

# %% [markdown]
# ## Data Insights through SQL

# %% [markdown]
# We intiate light analysis through SQLite3.
#
# In this next stage, we aim to create a database <span style ="color:green">openstreemap.db</span>. In this database, we have five tables. These five tables are:
#
# - nodes
# - nodes_tags
# - ways
# - ways_tags
# - ways_nodes
#
# Below is the schema for the above tables
#
# [SQL Schema](https://gist.github.com/swwelch/f1144229848b407e0a5d13fcb7fbbd6f)

# %% [markdown]
# ### Nodes Table

# %%
db = sqlite3.connect("Database/openstreetmap.db")
cursor = db.cursor()

# %%
create_nodes_table = '''
CREATE TABLE nodes (
id  INTEGER PRIMARY KEY NOT NULL,
lat REAL,
lon REAL,
user TEXT,
uid INTEGER,
version INTEGER,
changeset INTEGER,
timestamp TEXT
);'''
cursor.execute(create_nodes_table)

# %%
with open(NODES_PATH,'r') as source:
    diction = csv.DictReader(source)
    insert_query_nodes = '''INSERT INTO nodes(id, lat, lon, user, uid, version, changeset, timestamp) VALUES (?, ?, ?, ?, ?, ?, ?, ?);'''
    write_into_nodes = [(i['id'], i['lat'],i['lon'], i['user'], i['uid'], i['version'], i['changeset'], i['timestamp']) for i in diction]
    
cursor.executemany(insert_query_nodes, write_into_nodes)
db.commit()

# %%
query = "SELECT id FROM nodes LIMIT 2;"
cursor.execute(query)
rows = cursor.fetchall()
print(rows)
# Out:
# [(281266,), (30029498,)]

# %%
create_nodes_tags_table = '''
CREATE TABLE nodes_tags(
id INTEGER references nodes(id),
key TEXT,
value TEXT,
type TEXT
                                
);'''
cursor.execute(create_nodes_tags_table)

# %%
with open(NODE_TAGS_PATH,'r') as source2:
    diction2 = csv.DictReader(source2)
    insert_query_nodes_tags = '''INSERT INTO nodes_tags(id, key, value, type) VALUES (?,?,?,?);'''
    write_into_nodes_tags = [(i['id'], i['key'], i['value'], i['type']) for i in diction2]
cursor.executemany(insert_query_nodes_tags,write_into_nodes_tags)
db.commit()

# %%
query = "SELECT id FROM nodes_tags LIMIT 2;"
cursor.execute(query)
rows = cursor.fetchall()
print(rows)
# Out:
# [(30029498,), (30029498,)]

# %% [markdown]
# ### Ways Table

# %%
create_ways_table = '''
CREATE TABLE ways(
id INTEGER PRIMARY KEY NOT NULL,
user TEXT,
uid INTEGER,
version TEXT,
changeset INTEGER,
timestamp TEXT
);'''
cursor.execute(create_ways_table)

# %%
with open(WAYS_PATH,'r') as source3:
    diction3 = csv.DictReader(source3)
    insert_query_ways = '''INSERT INTO ways(id,user,uid,version,changeset,timestamp) VALUES(?,?,?,?,?,?);'''
    write_into_ways = [(i['id'],i['user'],i['uid'],i['version'],i['changeset'],i['timestamp']) for i in diction3]
cursor.executemany(insert_query_ways,write_into_ways)

# %%
query = '''SELECT * FROM ways LIMIT 2'''
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(5072896, 'dchiles', 153669, '6', 15865774, '2013-04-25T21:11:21Z'),
#  (6319364, 'Natfoot', 567792, '5', 33117782, '2015-08-05T04:59:42Z')]

# %% [markdown]
# ### Ways_Tags Table

# %%
create_ways_tags_table = '''
CREATE TABLE ways_tags(
id INTEGER NOT NULL,
key TEXT NOT NULL,
value TEXT NOT NULL,
type TEXT,
FOREIGN KEY (id) REFERENCES ways(id)
);
'''
cursor.execute(create_ways_tags_table)

# %%
with open(WAY_TAGS_PATH,'r') as source4:
    diction4 = csv.DictReader(source4)
    insert_query_ways_tags = '''INSERT INTO ways_tags(id,key,value,type) VALUES(?,?,?,?);'''
    write_into_ways_tags = [(i['id'],i['key'],i['value'],i['type']) for i in diction4]
cursor.executemany(insert_query_ways_tags,write_into_ways_tags)

# %%
query = '''SELECT * FROM ways_tags LIMIT 2'''
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(5072896, 'bicycle', 'no', 'regular'), (5072896, 'highway', 'path', 'regular')]

# %% [markdown]
# ### Ways Nodes Table

# %%
create_ways_nodes_table = '''
CREATE TABLE ways_nodes(
id INTEGER NOT NULL,
node_id INTEGER NOT NULL,
position INTEGER NOT NULL,
FOREIGN KEY (id) REFERENCES ways(id)
FOREIGN KEY (node_id) REFERENCES nodes(id)

);'''
cursor.execute(create_ways_nodes_table)

# %%
with open(WAY_NODES_PATH,'r') as source5:
    diction5 = csv.DictReader(source5)
    insert_query_ways_nodes = '''INSERT INTO ways_nodes(id,node_id,position) VALUES(?,?,?);'''
    write_into_ways_nodes = [(i['id'],i['node_id'],i['position']) for i in diction5]
cursor.executemany(insert_query_ways_nodes,write_into_ways_nodes)

# %%
query = '''SELECT * FROM ways_nodes LIMIT 2;'''
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(5072896, 34351369, 0), (5072896, 34351379, 1)]

# %% [markdown]
# ## Additional Questions from our OpenStreetMap Database

# %% [markdown]
# #### Top Contributor

# %%
query = '''SELECT uid, user, COUNT(uid) FROM nodes GROUP BY uid ORDER BY COUNT(uid) DESC;'''
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(94578, 'andygol', 13176),
#  (1240849, 'ediyes', 8534),
#  (1829683, 'Luis36995', 6410),
#  (2226712, 'dannykath', 4778),
#  (510836, 'Rub21', 3794),
#  (2219338, 'RichRico', 3613),
#  (2511706, 'calfarome', 1676),
#  (14293, 'KindredCoda', 1458),
#  (169004, 'oldtopos', 1366),
#  (2748195, 'karitotp', 1264),
#  (2512300, 'samely', 1140),
#  (2377377, 'abel801', 988),
#  (160138, 'DanHomerick', 825),
#  (2835928, 'nikhilprabhakar', 772),
#  (933797, 'oba510', 766),
#  (2015224, 'Jothirnadh', 530),
#  (55774, 'nmixter', 515),
#  (3029661, 'saikabhi', 505),
#  (153669, 'dchiles', 489),
#  (2915075, 'hmkandrey', 483),
#  (706170, 'BharataHS', 417),
#  (4845203, 'Ludmila Gladkova', 407),
#  (28775, 'StellanL', 392),
#  (381909, 'JessAk71', 391),
#  (3272286, 'manings', 389),
#  (371121, 'AndrewSnow', 388),
#  (2823295, 'ramyaragupathy', 382),
#  (2644101, 'Chetan_Gowda', 377),
#  (2905914, 'pratikyadav', 352),
#  (2715687, 'anonymoussparrow', 351),
#  (1249504, 'EranChazan', 301),
#  (147510, 'woodpeck_fixbot', 261),
#  (2115749, 'srividya_c', 249),
#  (11154, 'beej71', 233),
#  (3057995, 'oini', 220),
#  (941449, 'lyzidiamond', 218),
#  (210173, 'osmmaker', 215),
#  (1934489, 'brentengust', 199),
#  (91499, 'paulmach', 197),
#  (24452, 'Speight', 195),
#  (2847988, 'jinalfoflia', 190),
#  (22946, 'David Muir Sharnoff', 182),
#  (116029, 'Gregory Arenius', 150),
#  (36121, 'Chris Lawrence', 141),
#  (441116, 'immle', 128),
#  (2554698, 'ruthmaben', 101),
#  (1306, 'PlaneMad', 95),
#  (1295, 'robert', 94),
#  (2953895, 'warneke7', 94),
#  (65950, 'davetoo', 91),
#  (455164, 'Adityo', 89),
#  (2318, 'Latze', 86),
#  (397988, 'groove', 86),
#  (42429, '42429', 83),
#  (131996, 'nvk', 83),
#  (236172, 'saikofish', 82),
#  (402624, 'bdiscoe', 80),
#  (3344856, 'mestergaard', 75),
#  (2760218, 'blacktopol', 73),
#  (46789, 'jraller', 71),
#  (3158, 'Eric Fischer', 70),
#  (4847361, 'lowlamaps', 68),
#  (201724, 'mk408', 67),
#  (660287, 'Teslawire', 64),
#  (1376118, 'ChrisZontine', 62),
#  (35195, 'will l', 61),
#  (25510, 'Apo42', 60),
#  (22925, 'ELadner', 59),
#  (383461, 'phoenix23', 58),
#  (25604, 'db48x', 55),
#  (5116622, 'Mari G', 55),
#  (404841, 'jstratm', 54),
#  (462373, 'Davidazus', 54),
#  (482916, 'bill42', 54),
#  (242352, 'BK_man', 53),
#  (67236, 'jfire', 51),
#  (81024, 'wallclimber21', 51),
#  (25981, 'Michal Migurski', 50),
#  (120468, 'Gone', 49),
#  (4213591, 'timmmichaud', 49),
#  (4224929, 'mcmm', 49),
#  (192581, 'P Dill', 45),
#  (481533, 'dbaron', 45),
#  (361207, 'Ben Discoe', 44),
#  (355242, 'Bryce C Nesbitt', 43),
#  (2859289, 'Alps Pierrat', 41),
#  (532783, 'Eureka gold', 40),
#  (1762578, 'Hiker Dan', 40),
#  (4967074, 'KevinGillette', 39),
#  (202256, 'Telecas', 37),
#  (3877019, 'piligab', 37),
#  (162110, 'tahongawaka', 36),
#  (567792, 'Natfoot', 36),
#  (722137, 'OSMF Redaction Account', 36),
#  (119881, 'claysmalley', 35),
#  (635896, 'bigwebguy', 35),
#  (416346, 'Brian@Brea', 33),
#  (436419, 'wvdp', 33),
#  (1213904, 'mpmckenna8', 33),
#  (1679, 'andrewpmk', 32),
#  (564585, 'wegavision', 32),
#  (3260615, 'SFBay1234', 32),
#  (37067, 'barte', 31),
#  (383858, 'digital0533', 31),
#  (589596, 'lxbarth', 31),
#  (2049452, 'rthfer', 31),
#  (3526347, 'SikeMo', 30),
#  (3885962, 'Hokatah', 30),
#  (123633, 'stevea', 29),
#  (1249130, 'w1n5ton', 29),
#  (2985232, 'aarthy', 29),
#  (3207726, 'beddy', 29),
#  (156109, 'Falcorian', 28),
#  (143643, 'Gijsrooy', 26),
#  (195702, 'Sergey Kozyr', 26),
#  (243490, 'T99', 26),
#  (116769, 'probabble', 25),
#  (120160, 'dbuccolo', 25),
#  (1018369, 'sys49152', 25),
#  (53073, 'Aaron Lidman', 22),
#  (1519895, 'GwennDragon', 22),
#  (1850730, 'Morgan Herlocker', 22),
#  (321578, 'rabbitface', 21),
#  (621202, 'dpaschich', 21),
#  (103340, 'Davin', 20),
#  (595221, 'matthieun', 19),
#  (4325299, 'fjas510', 19),
#  (81497, 'RaffyO', 18),
#  (85177, 'edisonlow', 18),
#  (1884370, 'Nick L', 18),
#  (5359, 'user_5359', 17),
#  (574654, 'Tom_Holland', 17),
#  (584325, 'bhousel', 17),
#  (4523751, 'mrspie', 17),
#  (4971651, 'William Pigeon', 17),
#  (20587, 'balrog-kun', 16),
#  (79401, 'Alexander Avtanski', 16),
#  (190493, 'vonvonvon', 16),
#  (623324, 'Anton Lavrov', 16),
#  (902727, 'javbw', 15),
#  (1796809, 'doug_sfba', 15),
#  (3526564, 'yurasi', 15),
#  (103253, 'gormur', 14),
#  (732991, 'Nathan K', 14),
#  (1708763, 'Brobdingnag', 13),
#  (2474344, 'PH_Mapper', 13),
#  (3178375, 'LeTopographeFou', 13),
#  (3346582, 'GigglingMapper', 13),
#  (35667, 'encleadus', 12),
#  (38487, 'jumbanho', 12),
#  (106828, 'WimM', 12),
#  (145401, 'jnstahl', 12),
#  (214969, 'AndrewBuck', 12),
#  (2639622, 'RationalTangle', 12),
#  (3483725, 'nextuniverse', 12),
#  (5495681, 'JoanL', 12),
#  (19532, 'gaku', 11),
#  (330773, 'Roadrunner21', 11),
#  (760282, 'tsangkenneth', 11),
#  (1214881, 'ryandrake', 11),
#  (1692237, 'mikwat', 11),
#  (1835512, 'nereocystis', 11),
#  (38784, 'Tom Morris', 10),
#  (195150, 'Jesus arango', 10),
#  (239998, 'Sundance', 10),
#  (322034, 'jknewl', 10),
#  (479256, 'geodreieck4711', 10),
#  (837425, 'Jonathan ZHAO', 10),
#  (1247632, 'ipsofacto', 10),
#  (2229097, 'dougletterman', 10),
#  (5074162, 'Slam Garbage', 10),
#  (19235, 'glennon', 9),
#  (33757, 'Minh Nguyen', 9),
#  (123364, 'Tronikon', 9),
#  (171503, 'diskus69', 9),
#  (194231, 'Chris Bell in California', 9),
#  (1529919, 'jrpepper', 9),
#  (1597155, 'poornibadrinath', 9),
#  (1616228, 'flockfinder', 9),
#  (54585, 'Tom Brown', 8),
#  (199600, 'peastman', 8),
#  (207745, 'NE2', 8),
#  (224058, 'sethoscope', 8),
#  (365883, 'morganvenable', 8),
#  (548288, 'WayneSchlegel', 8),
#  (1722605, 'jimhu', 8),
#  (1817244, 'Helmchen42', 8),
#  (3049198, 'ryanderso', 8),
#  (3616263, 'Crabkilla', 8),
#  (5448688, 'HashTagAJay', 8),
#  (4951, 'PeterEastern', 7),
#  (262151, 'ToeBee', 7),
#  (318696, 'n76', 7),
#  (473717, 'thegpshiker', 7),
#  (550560, 'Seandebasti', 7),
#  (1577172, 'it_was_catch22', 7),
#  (1745338, '-MegaByte-', 7),
#  (2209894, 'Spanholz', 7),
#  (2245260, 'IndyMapper', 7),
#  (2747838, 'ssjazz', 7),
#  (364, 'Edward', 6),
#  (3095, 'Alan', 6),
#  (13840, 'mcdmx', 6),
#  (74292, 'Sarah M', 6),
#  (110263, 'werner2101', 6),
#  (183737, 'tkmedia', 6),
#  (190676, 'highbuilder', 6),
#  (336460, 'robgeb', 6),
#  (416100, 'AlistairA', 6),
#  (670691, 'Harry Cutts', 6),
#  (1494110, 'KristenK', 6),
#  (1733584, 'bugplanet', 6),
#  (2181142, 'lyiu', 6),
#  (2508151, 'ridixcr', 6),
#  (2411, 'Marc', 5),
#  (4732, 'iandees', 5),
#  (27454, 'Popolon', 5),
#  (28145, 'amillar', 5),
#  (47892, 'richlv', 5),
#  (79330, 'Jason Scheirer', 5),
#  (83660, 'Ashish Vijayaram', 5),
#  (152074, 'beweta', 5),
#  (158274, 'garmercman', 5),
#  (160949, 'eric22', 5),
#  (161619, 'FvGordon', 5),
#  (271668, 'David Sharnoff', 5),
#  (305001, 'voschix', 5),
#  (564990, 'mavl', 5),
#  (703517, 'Iowa Kid', 5),
#  (1110270, 'afdreher', 5),
#  (1779875, 'jeremiak', 5),
#  (2050600, 'fogfish', 5),
#  (2132368, 'icdawg', 5),
#  (2262733, 'BigD65', 5),
#  (2323512, 'Brian Reavis', 5),
#  (2764994, 'burritojustice', 5),
#  (3151684, 'Yoshinion', 5),
#  (3189680, 'angier1212', 5),
#  (3397814, 'fhmh', 5),
#  (3397845, 'szymanska', 5),
#  (4138943, 'wyleyr', 5),
#  (4386661, 'balalaika', 5),
#  (4510966, 'erchpito', 5),
#  (5094350, 'osmcrc', 5),
#  (6585, 'Martin Atkins', 4),
#  (14179, 'oakland', 4),
#  (54598, 'adbrown', 4),
#  (60612, 'Ratpick', 4),
#  (72002, 'Matt Heberger', 4),
#  (74275, 'balcoath', 4),
#  (135163, 'MikeN', 4),
#  (290680, 'wheelmap_visitor', 4),
#  (372674, 'edgehillnet', 4),
#  (573196, 'nithinkamath', 4),
#  (644152, 'npdoty', 4),
#  (1168909, 'ErikPottinger', 4),
#  (1194938, 'pdgoodman', 4),
#  (1529343, 'camilleanne', 4),
#  (1533136, 'meghanh', 4),
#  (1660455, 'juergenb22', 4),
#  (1711265, 'meliot', 4),
#  (1775756, 'ets_2016', 4),
#  (1836535, 'GITNE', 4),
#  (1893220, 'luckiegurl37', 4),
#  (2100843, 'allandaly', 4),
#  (2257567, 'RMap1', 4),
#  (2886207, 'pinakographos', 4),
#  (3397796, 'MiyagiMachine', 4),
#  (3521724, 'headwatersolver', 4),
#  (3696230, 'stkashani', 4),
#  (4225299, 'Alx303', 4),
#  (4899678, 'eavrdfsdcwad', 4),
#  (682, 'SteveC', 3),
#  (2177, 'bron', 3),
#  (21931, 'amm', 3),
#  (29017, 'FrankT', 3),
#  (46220, "Ethan O'Connor", 3),
#  (73268, 'drewda', 3),
#  (81909, 'jlev', 3),
#  (82807, 'jerememonteau', 3),
#  (93285, 'skela', 3),
#  (93788, 'coleman', 3),
#  (100744, 'fennecfoxen', 3),
#  (136211, 'AGWA', 3),
#  (138169, 'Barry Parr', 3),
#  (145231, 'woodpeck_repair', 3),
#  (154749, 'wiedmann', 3),
#  (174995, 'invliD', 3),
#  (322404, 'trevyn', 3),
#  (411298, 'Yury Yatsynovich', 3),
#  (431056, 'mbiker', 3),
#  (522320, 'forkbender', 3),
#  (593205, 'msdess', 3),
#  (597941, 'JeffM8', 3),
#  (634337, 'Snackdaddy', 3),
#  (637707, 'velonautian', 3),
#  (711243, 'Joseph Churchill', 3),
#  (982633, 'joesmith1234', 3),
#  (1098862, 'xj25vm', 3),
#  (1185712, 'Vanuan', 3),
#  (1212907, 'lcwong', 3),
#  (1346983, 'knotthere', 3),
#  (1425289, 'lucioperca', 3),
#  (1550640, 'Freddi2812', 3),
#  (1583864, 'andybaumgar', 3),
#  (1664082, 'MonoSim', 3),
#  (1917271, 'Adam Alpern', 3),
#  (1940279, 'theillustratedlife', 3),
#  (1951224, 'zoverax', 3),
#  (2022156, 'Mehi', 3),
#  (2441939, 'thevirginian', 3),
#  (2475974, 'Dilys', 3),
#  (2682147, 'danrademacher', 3),
#  (2886662, 'Xander Kittah', 3),
#  (3233629, 'Kim Mason', 3),
#  (3397842, 'Tiara Richard', 3),
#  (3479270, 'nammala', 3),
#  (3769434, 'manoharuss', 3),
#  (4007051, 'upendrakarukonda', 3),
#  (4503285, 'sjdunbar', 3),
#  (4518035, 'BenoitMenez', 3),
#  (5133699, 'godzilla94552', 3),
#  (5239832, 'BharataHS_laimport', 3),
#  (5257421, 'soundtcr', 3),
#  (8287, 'migurski', 2),
#  (8909, 'mvexel', 2),
#  (12055, 'aude', 2),
#  (12671, 'sladen', 2),
#  (24555, 'fmarier', 2),
#  (27781, 'Rodolphe Devillers', 2),
#  (27824, 'phut', 2),
#  (28923, 'California Bear', 2),
#  (29639, 'bielebog', 2),
#  (31385, 'Skippern', 2),
#  (37137, 'Derick Rethans', 2),
#  (40397, 'Zartbitter', 2),
#  (74705, 'Bike Mapper', 2),
#  (77582, 'Byung Kyu Park', 2),
#  (83557, 'Esperanza36', 2),
#  (88961, 'Shmias', 2),
#  (92286, 'Paul Johnson', 2),
#  (95132, 'Emers', 2),
#  (109968, 'InsomniaZZZ', 2),
#  (111529, 'ReinerMeyer', 2),
#  (117995, 'tbm', 2),
#  (125457, 'Orblivion', 2),
#  (128186, 'malcolmh', 2),
#  (131476, 'DMaximus', 2),
#  (138911, 'emancdf', 2),
#  (161951, 'DLichti', 2),
#  (172061, 'CloCkWeRX', 2),
#  (278150, 'GeoTomDe', 2),
#  (291298, 'pkm', 2),
#  (296869, 'Zian Choy', 2),
#  (381253, 'MichaelGSmith', 2),
#  (398300, 'baditaflorin', 2),
#  (429728, 'bnewey', 2),
#  (432824, 'snwnj', 2),
#  (473980, 'earthiq', 2),
#  (492311, 'zacmccormick', 2),
#  (501715, 'rkuris', 2),
#  (507503, 'caior', 2),
#  (529836, 'farad', 2),
#  (594525, 'esuor', 2),
#  (665694, 'aarp65', 2),
#  (696201, 'denimboy', 2),
#  (701297, 'erjiang', 2),
#  (714898, 'Md Alamgir', 2),
#  (775006, 'ORDG', 2),
#  (829302, 'Claudev8', 2),
#  (1083211, 'Theo D O Lite', 2),
#  (1168707, 'animeigo', 2),
#  (1297360, 'eepsmedia', 2),
#  (1403907, 'VMukhtarov', 2),
#  (1476146, 'Alecs01', 2),
#  (1546527, 'dirtysouth', 2),
#  (1707766, 'Christine_E', 2),
#  (1710478, 'SpannedObjurgations', 2),
#  (1781831, 'Bob12345', 2),
#  (1802220, 'jonesydesign', 2),
#  (1850735, 'rgupta0747', 2),
#  (1886770, 'BHSPitMonkey', 2),
#  (1980416, 'olikami', 2),
#  (2045423, 'Dave Guarino', 2),
#  (2136684, 'senordanimal', 2),
#  (2240409, 'Ryan Scott', 2),
#  (2240804, 'Paul Everett', 2),
#  (2254670, 'Andrew Ash', 2),
#  (2328400, 'jaapweel', 2),
#  (2376998, 'Tim_the_toolman', 2),
#  (2389416, 'lmitchell', 2),
#  (2406567, 'eddietejeda', 2),
#  (2406578, 'colindt', 2),
#  (2412184, 'youngbasedallah', 2),
#  (2422893, 'volki123', 2),
#  (2575095, 'enveloper', 2),
#  (2655992, 'steverumizen', 2),
#  (2724074, 'WorldWatchOne', 2),
#  (2733735, 'jnmiller', 2),
#  (2876693, 'sayreot', 2),
#  (3081437, 'fproulx', 2),
#  (3109007, 'mrkooll', 2),
#  (3181637, 'scottjohnson3', 2),
#  (3397844, 'warrenwong', 2),
#  (3478684, 'GoWestTravel', 2),
#  (3569951, '00crashtest', 2),
#  (3587922, 'Fishytodd', 2),
#  (3681372, 'NWR6', 2),
#  (4095244, 'askklein', 2),
#  (4109236, 'liammc2000', 2),
#  (4724512, 'leftcoastnaturalist', 2),
#  (4801391, 'Claumires', 2),
#  (4893098, 'saikabhi_sfimport', 2),
#  (5185806, 'jmtyndall', 2),
#  (6113775, 'n_LH', 2),
#  (735, 'blackadder', 1),
#  (999, 'mikelmaron', 1),
#  (1697, 'nickb', 1),
#  (3516, 'BiIbo', 1),
#  (3990, 'YannC', 1),
#  (4115, 'Andy Allan', 1),
#  (4902, 'mbuege', 1),
#  (5211, 'emvee', 1),
#  (6367, 'mackerski', 1),
#  (6975, 'ulfl', 1),
#  (11711, 'Octoferret', 1),
#  (13192, 'delphiN', 1),
#  (14351, 'WBSKI', 1),
#  (16478, 'Raymond', 1),
#  (23762, 'Heptazane', 1),
#  (25867, 'adamos', 1),
#  (25996, 'pingoo', 1),
#  (26599, 'cdavila', 1),
#  (28559, 'Stemby', 1),
#  (30360, 'novakyu', 1),
#  (31231, 'Andre68', 1),
#  (31906, 'ago1024', 1),
#  (32952, 'DennisL', 1),
#  (35254, 'Zer', 1),
#  (35372, 'suspet', 1),
#  (35935, '13 digits', 1),
#  (37753, 'Max Spring', 1),
#  (38090, 'ZekeFarwell', 1),
#  (44389, 'kollokollo', 1),
#  (45611, 'Srittau', 1),
#  (48060, 'Sat', 1),
#  (51581, 'dandv', 1),
#  (52797, 'hofoen', 1),
#  (53936, 'elsaxo', 1),
#  (53964, '_Mathieu_', 1),
#  (58305, 'fiveisalive', 1),
#  (70092, 'tcarobruce', 1),
#  (70696, 'xybot', 1),
#  (74228, 'nateirwin', 1),
#  (86066, 'Joel Franusic', 1),
#  (87731, 'Serguei Trouchelle', 1),
#  (88771, 'mjn', 1),
#  (93800, 'Alan Vogt', 1),
#  (100467, 'johnnyishellarad', 1),
#  (104461, 'brunosan', 1),
#  (104519, 'Rupert Swarbrick', 1),
#  (105946, 'ElliottPlack', 1),
#  (107257, 'FrViPofm', 1),
#  (107681, 'maxugglan', 1),
#  (113624, 'mojodna', 1),
#  (120664, 'Chris Clemson', 1),
#  (126019, 'Jarrattp', 1),
#  (130277, 'Teuxe', 1),
#  (135329, 'ajashton', 1),
#  (143856, 'axelbaker', 1),
#  (144449, 'mpetrotta', 1),
#  (148776, 'meridianeum', 1),
#  (148800, 'AndreasPr', 1),
#  (163803, 'jjmcgaffey', 1),
#  (171516, 'Caboosey', 1),
#  (173918, 'njaard', 1),
#  (174586, 'NAParish', 1),
#  (178186, 'mdk', 1),
#  (185205, 'magnunor', 1),
#  (186357, 'liucougar', 1),
#  (190690, 'posiki', 1),
#  (190869, 'elbatrop', 1),
#  (192522, 'thecrazyknitter', 1),
#  (192954, 'ptancredi', 1),
#  (206785, 'Tom O', 1),
#  (231017, 'swimdb', 1),
#  (231723, 'sfllaw', 1),
#  (235835, 'lizhenry', 1),
#  (238419, 'g246020', 1),
#  (252811, 'rickmastfan67', 1),
#  (257555, 'rene78', 1),
#  (257972, 'Peakfinder', 1),
#  (272522, 'ramayer', 1),
#  (286975, 'Jesper Jurcenoks', 1),
#  (290016, 'atsiatas', 1),
#  (296587, 'bmhr', 1),
#  (296793, 'kouker', 1),
#  (297064, 'HeyIdiot', 1),
#  (303224, 'Mignon', 1),
#  (305985, 'ingalls', 1),
#  (329833, 'pankdm', 1),
#  (338351, 'sfodoug', 1),
#  (338843, 'TorCguy', 1),
#  (341519, 'lcmortensen', 1),
#  (347787, 'farsak', 1),
#  (349023, 'jdhall', 1),
#  (352170, 'dspring', 1),
#  (360392, 'maxerickson', 1),
#  (363927, 'Brian H Wilson', 1),
#  (366306, 'derricknehrenberg', 1),
#  (371711, 'knockpenny', 1),
#  (401490, 'svance92', 1),
#  (412560, 'Meersbrook', 1),
#  (415728, 'sycamore_island', 1),
#  (429804, 'hazzardsb', 1),
#  (450292, 'aguynamedben', 1),
#  (475877, 'RoadGeek_MD99', 1),
#  (482974, 'ogremage', 1),
#  (485507, 'Sam Maurer', 1),
#  (521541, 'domob', 1),
#  (530149, 'Mapper1', 1),
#  (540553, 'ki6uoc', 1),
#  (545896, 'shitonfools', 1),
#  (574053, 'Walk and walk around', 1),
#  (583866, 'deinefreunde', 1),
#  (588517, 'M_Aloisius', 1),
#  (606225, 'fizzymagic', 1),
#  (613191, 'conf88', 1),
#  (620663, 'Peter Shank', 1),
#  (626299, 'Andrew Kraut', 1),
#  (627528, 'emilyann5', 1),
#  (632124, 'duxxa', 1),
#  (638133, 'LoicSf', 1),
#  (643201, 'lbacud', 1),
#  (652230, 'hichmont', 1),
#  (667422, 'Alex-7', 1),
#  (672542, 'Nearo', 1),
#  (674313, 'snowey', 1),
#  (676820, 'shivanshu', 1),
#  (698697, 'powell789', 1),
#  (743575, 'pescorosso', 1),
#  (745333, 'ustroetz', 1),
#  (828519, 'Cjlanda', 1),
#  (860575, 'MarcelHerault', 1),
#  (901335, 'Sasharef', 1),
#  (902185, 'synack440', 1),
#  (908886, 'masterleep', 1),
#  (916555, 'NLgis', 1),
#  (945595, 'jo-mey', 1),
#  (950182, 'RitterR', 1),
#  (1044834, 'Jesse Phillips', 1),
#  (1087647, 'Phil Scherer', 1),
#  (1154880, 'AntonBryl', 1),
#  (1195290, 'cjacky', 1),
#  (1210008, 'mnorelli', 1),
#  (1211007, 'OYR', 1),
#  (1211556, 'dbaupp', 1),
#  (1212745, 'YraFyra', 1),
#  (1213894, 'Bradley Cleveland', 1),
#  (1240864, 'Howpper', 1),
#  (1260280, 'jacobbraeutigam', 1),
#  (1282393, 'Reno Editor', 1),
#  (1309137, 'bobnewey', 1),
#  (1323941, 'dnomadb', 1),
#  (1355899, 'isabellekh', 1),
#  (1393741, 'pollardld', 1),
#  (1408707, 'YongYang', 1),
#  (1430178, 'Jonathon Conte', 1),
#  (1431737, 'ma-rt-in', 1),
#  (1529374, 'Davis Kitchel', 1),
#  (1556219, 'Thibaut75011', 1),
#  (1611887, 'Scott13208', 1),
#  (1720031, 'BerkelBear', 1),
#  (1722904, 'Alan Trick', 1),
#  (1731525, 'hmyers909', 1),
#  (1733620, 'kdingman', 1),
#  (1750383, 'ljjwfr', 1),
#  (1751737, 'Skybunny', 1),
#  (1758880, 'DongyangCA', 1),
#  (1778256, 'theojapa', 1),
#  (1797586, 'jschill', 1),
#  (1814324, 'VrindaM', 1),
#  (1860668, 'Walkabout44', 1),
#  (1861330, 'RBF', 1),
#  (1883329, 'FactChecker', 1),
#  (1887210, 'Aaronmap', 1),
#  (1926148, 'codesliced', 1),
#  (1942315, 'RhinoCreature', 1),
#  (1959811, 'ub91', 1),
#  (1964364, 'Eseqko', 1),
#  (1976641, 'Gpriceless', 1),
#  (1980274, 'dhalli1', 1),
#  (1980320, 'kingpenguin', 1),
#  (1980326, 'jmadeline', 1),
#  (2012449, 'Dami_Tn', 1),
#  (2012966, 'emejim', 1),
#  (2016549, 'NPLC', 1),
#  (2017972, 'Mr0grog', 1),
#  (2021999, 'david_ozer', 1),
#  (2032360, 'Drew1sh', 1),
#  (2032478, 'SarahStierch', 1),
#  (2033336, 'AnnieM', 1),
#  (2035254, 'Devin Swisher', 1),
#  (2045275, 'anaris328', 1),
#  (2052335, 'James Fahlbusch', 1),
#  (2052349, 'Michael Webster', 1),
#  (2061773, 'sorchah', 1),
#  (2076173, 'Kasey Klimes', 1),
#  (2086526, 'RyJoh', 1),
#  (2137840, 'rza31', 1),
#  (2176692, 'David Strauss', 1),
#  (2306749, 'shvrm', 1),
#  (2332032, 'thatmm', 1),
#  (2334541, '0101010', 1),
#  (2363939, 'MenloJim', 1),
#  (2370549, 'rstoeber', 1),
#  (2393795, 'Daniel Specht', 1),
#  (2411240, 'pluton_od', 1),
#  (2411764, 'wilmette88', 1),
#  (2433512, '75287578', 1),
#  (2488002, 'Michael Steffen', 1),
#  (2524341, 'UI Guy', 1),
#  (2580175, 'bravo7265', 1),
#  (2590582, 'MannequinBaby', 1),
#  (2593828, 'pizza4days', 1),
#  (2601744, 'sctrojan79', 1),
#  (2688775, 'Warren T', 1),
#  (2697733, 'Gizmot', 1),
#  (2763448, 'Daniel_Caldwell', 1),
#  (2773196, 'NickBolten', 1),
#  (2813257, 'CamRobDen', 1),
#  (2814663, 'Ballard OpenStreetMap', 1),
#  (2819599, 'CaseyFrost', 1),
#  (2820500, 'a6y', 1),
#  (2866692, 'glotto', 1),
#  (2880297, 'LimaMoon', 1),
#  (2883452, 'vbgt', 1),
#  (2884337, 'cercis14', 1),
#  (2903274, 'trosm', 1),
#  (2925215, 'houston_mapper1', 1),
#  (2941385, 'cart0', 1),
#  (2944689, 'mihaii_telenav', 1),
#  (2967601, 'alpinekid', 1),
#  (3125856, 'cowdog', 1),
#  (3129859, 'kmarseglia', 1),
#  (3215437, 'Isabel Wang', 1),
#  (3224809, 'Ken Johnson 2', 1),
#  (3282935, 'Blaxcarab', 1),
#  (3324338, 'janp2001', 1),
#  (3389275, 'cmdoptesc', 1),
#  (3397534, 'nemo92', 1),
#  (3397835, 'KaylanHager', 1),
#  (3397837, 'bpace1994', 1),
#  (3397838, 'jtbrown1806', 1),
#  (3397846, 'Cherry24', 1),
#  (3397848, 'JM7323', 1),
#  (3415446, 'cylexx', 1),
#  (3415463, 'bjkosm', 1),
#  (3469870, 'Fan Kong', 1),
#  (3528573, 'ulrich_', 1),
#  (3558911, 'Joel S', 1),
#  (3601534, 'egavril', 1),
#  (3624816, 'cyeager89', 1),
#  (3665135, 'William Carman', 1),
#  (3671294, 'cynmar', 1),
#  (3696204, 'dsherrell', 1),
#  (3696208, 'pmeehan', 1),
#  (3696212, 'jaylina', 1),
#  (3696217, 'Kristymarie42', 1),
#  (3696439, 'Audey Seawright', 1),
#  (3762030, 'Stephanie Landa', 1),
#  (3793530, 'Jenn Kaplan', 1),
#  (3812920, 'Olivia De Lancie', 1),
#  (3830366, 'Asif Haque', 1),
#  (3886701, 'stepps00', 1),
#  (3905761, 'cplank', 1),
#  (3913914, 'Airlobster', 1),
#  (3916314, 'dschulle', 1),
#  (3995305, 'Travl', 1),
#  (4157731, 'Sandeep Venkatesh', 1),
#  (4158534, 'livets123', 1),
#  (4314582, 'MappedReduced', 1),
#  (4319107, 'Ty8769', 1),
#  (4353543, 'IbolyaTarsoly', 1),
#  (4460614, 'keikoanl', 1),
#  (4541740, 'Frank Vandevoorde', 1),
#  (4543547, 'sea2sky', 1),
#  (4624663, 'Doug777', 1),
#  (4635105, 'jcdoll', 1),
#  (4651319, 'jveeb', 1),
#  (4681914, 'Casey Bell', 1),
#  (4706158, 'brianshotwell', 1),
#  (4725451, 'DrSeamons', 1),
#  (4835230, 'KengS', 1),
#  (4846473, 'chaoman', 1),
#  (4892650, 'manings_sfheight', 1),
#  (5007769, 'UltraNivlac', 1),
#  (5024957, 'aquaplumb', 1),
#  (5084247, 'liesliesliesyea', 1),
#  (5147743, 'Jason Roy', 1),
#  (5148403, 'Darragh_M', 1),
#  (5183376, 'das-gus', 1),
#  (5184971, 'mllefoo', 1),
#  (5187925, 'aihardin', 1),
#  (5193438, 'Keykeys', 1),
#  (5193764, 'facecraft', 1),
#  (5204588, 'Tom_Servo', 1),
#  (5210438, 'KingDedede', 1),
#  (5222544, 'gnomad83', 1),
#  (5236034, 'Jenny Redo', 1),
#  (5367179, 'Rene415', 1),
#  (5400451, 'Alex Kapranoff', 1),
#  (5475233, 'MrJamesonNeat', 1),
#  (5486800, 'primes', 1),
#  (5667998, 'ArgonHunter', 1),
#  (5853065, 'McKinley D', 1),
#  (6008115, 'm2kw6s', 1),
#  (6106546, 'dharber', 1),
#  (6144079, 'AdaLowe', 1)]

# %% [markdown]
# Recalling the most contributing statistic from our python code, we confirm that user <span style="color:red">94578, andygol,</span> was the user that contributed most to SF Map entries
#
# nmixter's contribution ratio was

# %%
print(13176/65712,"percent")
# Out:
# 0.20051132213294376 percent

# %% [markdown]
# From the fact that the total OpenStreetMap South Modesto entries was 11607, as seem below

# %%
query = '''SELECT COUNT(uid) FROM nodes;'''
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(65712,)]

# %% [markdown]
# #### Top Contributor andygol's track

# %% [markdown]
# What locations did andygol contribute to?

# %%
query = '''SELECT lat, lon FROM nodes WHERE user = 'andygol' LIMIT 5;'''
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(37.8166239, -122.1905843),
#  (37.6197213, -122.0889768),
#  (37.6166747, -122.0922437),
#  (37.7852169, -122.183983),
#  (37.7961488, -122.1754563)]

# %% [markdown]
# I was curious who the user nmixter was. So, I found his profile on OpenStreetMap. In [Andygol's profile](https://www.openstreetmap.org/user/andygol), we observe that we has made 20,000+ entries over his 8 years as an OSM contributor.
#
# His SF contributions were created several months ago, and he still continues to expand out into Russia and San Jose entries. I.e., Andygol may be no SF native, but just a high contributor on OSM.
#
# If you go to this [link](https://www.mapbox.com/about/team/andrey-golovin/), you can actually find out that the OSM contributions are a part of his career and hobbies.
#
#
# $ $
#
# Now, let's continue to the nodes_tags table

# %% [markdown]
# ### Node Tags Table Insights

# %% [markdown]
# #### Verifying Street names from previous example

# %%
query = '''SELECT value FROM nodes_tags WHERE key = 'street';'''
cursor.execute(query)
rows = cursor.fetchall()
print(rows)
# Out:
# [('Cutting Boulevard',), ('Center Street',), ('Montgomery Street',), ('Beach Street',), ('Sutter Street',), ('San Pablo Avenue',), ('Shattuck Avenue',), ('Cedar Street',), ('Rose Street',), ('Eunice Street',), ('Berryman Street',), ('Northgate Avenue',), ('Shasta Road',), ('Spruce Street',), ('Cragmont Avenue',), ('Regal Road',), ('Grant Street',), ('Union Street',), ('Los Angeles Avenue',), ('Union Landing Boulevard',), ('Post Street',), ('Fort Mason Center',), ('Steiner Street',), ('Berryman Street',), ('The Alameda',), ('Yosemite Road',), ('Montrose Road',), ('Martin Luther King Jr Way',), ('Martin Luther King Jr Way',), ('Vine Street',), ('Keeler Avenue',), ('El Camino Real',), ('Decoto Road',), ('Alvarado-Niles Road',), ('Alvarado-Niles Road',), ('Decoto Road',), ('Hamilton Street',), ('University Avenue',), ('Telegraph Avenue',), ('Gateview Court',), ('Mariner Drive',), ('El Camino Real',), ('George Avenue',), ('Avenue of the Palms',), ('Decoto Road',), ('14th Street',), ('Walter Street',), ('El Camino Real',), ('El Camino Real',), ('Broadway',), ('Broadway',), ('9th Street',), ('Josephine Street',), ('Josephine Street',), ('Milvia Street',), ('Bonita Avenue',), ('Cedar Street',), ('Townsend Street',), ('Lombard Street',), ('Cedar Street',), ('25th Street',), ('Grant Street',), ('Valencia Street',), ('Kearny Street',), ('Broadway',), ('Polk Street',), ('Dwight Way',), ('Taraval Street',), ('Mission St',), ('Castro Street',), ('Castro Street',), ('Jefferson Street',), ('Church Street',), ('University Avenue',), ('10th Avenue',), ('Michael Drive',), ('7th Avenue',), ('Arguello Street',), ('Alden Street',), ('4th Street',), ('Main Street',), ('Heller Street',), ('Hopkins Avenue',), ('Roosevelt Avenue',), ('Fulton Street',), ('El Camino Real',), ('Upland Road',), ('Upland Road',), ('Saint Francis Street',), ('Ruby Street',), ('Reese Street',), ('Valota Road',), ('Kentfield Avenue',), ('Kentfield Avenue',), ('Oxford Street',), ('Woodside Road',), ('Wheeler Avenue',), ('Jefferson Court',), ('Oak Avenue',), ('Roosevelt Avenue',), ('Main Street',), ('College Avenue',), ('Howard Street',), ('Grand Avenue',), ('Santa Cruz Avenue',), ('Blanding Avenue',), ('Sanchez Street',), ('Jersey Street',), ('24th Street',), ('25th Street',), ('Clipper Street',), ('Guerrero Street',), ('Church Street',), ('24th Street',), ('Washington Street',), ('Stryker Street',), ('Sanchez Street',), ('Sanchez Street',), ('Sanchez Street',), ('24th Street',), ('27th Street',), ('Orange Street',), ('Virginia Avenue',), ('Macdonald Avenue',), ('Church Street',), ('South 17th Street',), ('Potrero Avenue',), ('College Avenue',), ('27th Street',), ('Duncan Street',), ('Valley Street',), ('29th Street',), ('Manor Plaza',), ('29th Street',), ('25th Street',), ('3rd Street',), ('Fair Oaks Street',), ('Fair Oaks Street',), ('Oxford Street',), ('West Portal Avenue',), ('Dolores Street',), ('Day Street',), ('West Portal Avenue',), ('Taraval Street',), ('Mission Street',), ('Larkin Street',), ('9th Avenue',), ('Irving Street',), ('Sansome Street',), ('Lawton Street',), ('Irving Street',), ('12th Avenue',), ('Judah Street',), ('9th Avenue',), ('7th Avenue',), ('Dolores Street',), ('Funston Avenue',), ('12th Avenue',), ('10th Avenue',), ('Dolores Street',), ('Funston Avenue',), ('Geary Street',), ('Carl Street',), ('Carl Street',), ('Willard Street',), ('3rd Avenue',), ('14th Street',), ('Carl Street',), ('Carl Street',), ('3rd Avenue',), ('Lincoln Way',), ('Bayshore Highway',), ('Irving Street',), ('3rd Avenue',), ('Carl Street',), ('9th Street',), ('Irving Street',), ('34th Avenue',), ('Irving Street',), ('Irving Street',), ('34th Avenue',), ('22nd Street',), ('MacArthur Boulevard',), ('5th Avenue',), ('Taraval Street',), ('48th Avenue',), ('Terrace Way',), ('Ocean Avenue',), ('Powell Street',), ('Dore Street',), ('Lincoln Way',), ('17th Street',), ('Corbett Avenue',), ('San Pablo Avenue',), ('Balboa Street',), ('Natoma Street',), ('Judah Street',), ('Mission Street',) ...

# %% [markdown]
# There were no necessary corrections for our street names in the initial audit of our street_names. The above output is a confirmation that our data is validated for the right entries and proper export to a csv file

# %%
query = '''SELECT value FROM nodes_tags WHERE key = 'postcode';'''
cursor.execute(query)
rows = cursor.fetchall()
print(rows)
# Out:
# [('94804',), ('94109',), ('94104',), ('94709',), ('94587',), ('94117',), ('94066',), ('94587',), ('94587',), ('94587',), ('94587',), ('94063',), ('94609',), ('94063',), ('94555',), ('94063',), ('94063',), ('94063',), ('94063',), ('94107',), ('94063',), ('94109',), ('94704',), ('94116',), ('94110',), ('94114',), ('94114',), ('94618',), ('94103',), ('94610',), ('94501',), ('94610',), ('94044',), ('94704',), ('94127',), ('94127',), ('94116',), ('94105',), ('94109',), ('94122',), ('94122',), ('94104',), ('94122',), ('94122',), ('94122',), ('94122',), ('94122',), ('94122',), ('94122',), ('94122',), ('94122',), ('94122',), ('94109',), ('94117',), ('94117',), ('94117',), ('94122',), ('94117',), ('94117',), ('94122',), ('94122',), ('94010',), ('94122',), ('94122',), ('94117',), ('94103',), ('94122',), ('94122',), ('94122',), ('94122',), ('94121',), ('94602',), ('94122',), ('94116',), ('94549',), ('94127',), ('94103',), ('94122',), ('94117',), ('94114',), ('94706',), ('94103',), ('94105',), ('94530',), ('94541',), ('94111',), ('94501',)]

# %% [markdown]
# Additionally, we observe no zipcode issues factored into our export file

# %% [markdown]
# #### Initial Discoveries

# %%
query = '''SELECT DISTINCT(key) FROM nodes_tags LIMIT 15;'''
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [('ref',),
#  ('exit_to',),
#  ('highway',),
#  ('source',),
#  ('created_by',),
#  ('barrier',),
#  ('traffic_signals',),
#  ('sound',),
#  ('turn_restrictions',),
#  ('crossing',),
#  ('noexit',),
#  ('ele',),
#  ('name',),
#  ('is_in',),
#  ('place',)]

# %% [markdown]
# We observe the first 15 types of keys from the nodes_tags table. These keys allow us to observe the listed attributes/descriptions of the SF region.
#
# For example, below is the first 5 listed highways in the SF region data:

# %%
query = "SELECT * FROM nodes_tags WHERE key ='highway' LIMIT 5"
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(30029498, 'highway', 'motorway_junction', 'regular'),
#  (33154450, 'highway', 'motorway_junction', 'regular'),
#  (53019140, 'highway', 'stop', 'regular'),
#  (53021162, 'highway', 'turning_circle', 'regular'),
#  (53027114, 'highway', 'turning_circle', 'regular')]

# %% [markdown]
# and below is the sport key(s) associated with our nodes_tags table:

# %%
query = "SELECT * FROM nodes_tags WHERE key ='sport'"
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(585968188, 'sport', 'gymnastics', 'regular'),
#  (1337779817, 'sport', 'martial_arts', 'regular')]

# %% [markdown]
# It's weird how there is only two sport entries, namely gymnastics and martial arts. I assume this value implies an OSM user indicated only two sports in SF.
#
#
# $ $
#
# Let's see the location(latitude,longitude) for these 'gymnastic' and 'martial_arts' value.

# %%
query = "SELECT * FROM nodes JOIN nodes_tags ON nodes.id = nodes_tags.id WHERE nodes_tags.value = 'gymnastics' OR nodes_tags.value = 'martial_arts';"
cursor.execute(query)
rows = cursor.fetchall()
pprint.pprint(rows)
# Out:
# [(585968188,
#   37.758916,
#   -122.43792,
#   'Jarrattp',
#   126019,
#   1,
#   3346849,
#   '2009-12-11T06:26:06Z',
#   585968188,
#   'sport',
#   'gymnastics',
#   'regular'),
#  (1337779817,
#   37.4667705,
#   -122.2080786,
#   'peastman',
#   199600,
#   3,
#   11812253,
#   '2012-06-06T04:54:26Z',
#   1337779817,
#   'sport',
#   'martial_arts',
#   'regular')]

# %% [markdown]
# Okay, We observe user <span style="color:red">Jarrattp and peastman </span> created these gymnastic and martial arts values, respectively.
#
# $ $
#
# Jarrattp's node for the gymastic entry is located at (37.758916, -122.43792)
#
# ![Gynmnastic's Location](Images/gymnastics_location.JPG)
#
# $ $
#
# Peastman's node for the martial arts entry is located at (37.4667705, -122.2080786)
#
# $ $
#
# ![Martial Arts Location](Images/martial_arts_location.JPG)

# %%
db.close()

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Input Recommendations**
# We observed the sparse osm file southmodesto.osm needed to be audited before fully importing and creating a database off of it. Integrity in our data should be the overall theme for this and several other datasets.
#
# To either avoid mishaps of entered data, here are some recommendations:
#
# - Create a input guideline for users.
# - Set conditions on entry boxes to avoid incorrect submissions
# - Inputing missing values from other values within the same node.
# - Using third party data  to cross validate and improve the dataset.
# - Create a preliminary warning "Are you sure this is the correct input" before final submission
#
# With these ideas being implemented, we provide additional ease in importing and transforming data. I.e., With these above conditions being implemented, the data analyst's dirty work(data wrangle) becomes more tolerable.
#
# <span style = "color:purple"> **Note:**
# If administrators continue data wrangling procedures without the implementation of the above recommendations, the administrator needs to ensure that the data cleaning does not create data loss of important user entries </span>
#
# **Consequences**
#
# The potential problems of implementing these solutions is user satisfaction of using services. If a user keeps on receiving notifications or warnings in submission process, the likelyhood of the user using are services diminishes.
#
# We can solve these potential problems when implementing the above solutions by providing examples along the entry locations.
# In putting in your birth in an online application, there usually is a provided example of how to enter your birthdate like so:
#
# [___ENTER HERE____] <span style="color:red">(Ex. MM/DD/YYYY)</span>
#
# User instructions with our recommended solutions provide a balance between user actions and administrative needs. Therefore, the likelyhood of a diminished retention rate would not change significantly.
#
#
# With these above ideas being implemented, we provide a more sound import process of our data into our required data format.

# %% [markdown]
# # End
