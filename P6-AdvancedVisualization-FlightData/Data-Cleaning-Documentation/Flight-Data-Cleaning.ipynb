# %% [markdown]
# # Data Cleaning Flight Information

# %% [markdown]
# ## Data Import and Inspection
#
# This is the documentation for the 2006-2010 Flight Dataset. In this document, we generate a new feature, impute ill-inputed/converted data values, and finalize data properties and features for data analysis implementation.
#
# ### Import

# %%
from zipfile import ZipFile as zp
import numpy as np
import pandas as pd
import string

import time

import matplotlib.pyplot as plt

# %%
def get_csv_file(filename):
    t0 = time.time()
    with zp('../Data/RawData/{}.zip'.format(filename)) as flight_zpfl:
        with flight_zpfl.open('{}.csv'.format(filename)) as f_info:
            dataframe =pd.read_csv(f_info,delimiter=',')
    print("Import loading time was {} seconds".format(time.time()-t0))
    return(dataframe)

# %%
df_flights = get_csv_file('783548897_52017_1328_airline_delay_causes')
# Out:
# Import loading time was 0.5884170532226562 seconds

# %% [markdown]
# ### Dataset Inspection
#
# This section observes several attributes of the flight dataset.

# %%
df_flights.shape
# Out:
# (91837, 22)

# %% [markdown]
# This dataset contains 91837 rows and 22 features.

# %%
df_flights.head(2)
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2006       8      AA  American Airlines Inc.     ABQ
# 1  2006       8      AA  American Airlines Inc.     ANC
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...        310.0       73.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...         62.0       38.0
#
#    carrier_ct   weather_ct     ...       late_aircraft_ct  arr_cancelled  \
# 0       17.53         8.83     ...                  26.51            5.0
# 1       11.53         0.88     ...                  11.27            0.0
#
#    arr_diverted   arr_delay   carrier_delay  weather_delay  nas_delay  \
# 0           1.0      3742.0           838.0          585.0      729.0
# 1           0.0      2605.0           879.0          100.0      870.0
#
#    security_delay  late_aircraft_delay  Unnamed: 21
# 0            21.0               1569.0          NaN
# 1             0.0                756.0          NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# We observe a random space " " in two feature titles (e.g. " month"). The following checks if some space exists in a feature title, and removes it.

# %%
col_names = list(df_flights.columns)
col_names_new =[]
for i in col_names:
    col_names_new.append(i.strip(" "))

# %%
print(col_names_new)
# Out:
# ['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name', 'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct', 'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted', 'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay', 'Unnamed: 21']

# %% [markdown]
# The above list confirms corrections of existing whitespace in feature titles. We now replace this list of corrected titles to the old flight dataframe's title.

# %%
df_flights.columns = col_names_new

# %%
df_flights.dtypes
# Out:
# year                     int64
# month                    int64
# carrier                 object
# carrier_name            object
# airport                 object
# airport_name            object
# arr_flights            float64
# arr_del15              float64
# carrier_ct             float64
# weather_ct             float64
# nas_ct                 float64
# security_ct            float64
# late_aircraft_ct       float64
# arr_cancelled          float64
# arr_diverted           float64
# arr_delay              float64
# carrier_delay          float64
# weather_delay          float64
# nas_delay              float64
# security_delay         float64
# late_aircraft_delay    float64
# Unnamed: 21            float64
# dtype: object

# %% [markdown]
# Lastly, we provide some descriptive statistics for the "df_flights" dataset.

# %%
df_flights.describe()
# Out:
#                year         month   arr_flights     arr_del15    carrier_ct  \
# count  91837.000000  91837.000000  91653.000000  91623.000000  91653.000000
# mean    2007.968847      6.492198    376.501675     80.083298     22.397971
# std        1.399134      3.445474   1008.399764    221.292022     49.784500
# min     2006.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2007.000000      4.000000     62.000000     12.000000      4.320000
# 50%     2008.000000      6.000000    125.000000     28.000000     10.000000
# 75%     2009.000000      9.000000    269.000000     62.000000     21.710000
# max     2010.000000     12.000000  15993.000000   4966.000000   1792.070000
#
#          weather_ct        nas_ct   security_ct  late_aircraft_ct  \
# count  91653.000000  91653.000000  91653.000000      91653.000000
# mean       2.980848     27.622592      0.212576         26.843168
# std       11.647614     98.159085      1.026079         82.746186
# min        0.000000      0.000000      0.000000          0.000000
# 25%        0.000000      2.290000      0.000000          1.960000
# 50%        0.810000      6.870000      0.000000          6.790000
# 75%        2.390000     17.510000      0.000000         18.670000
# max      641.540000   2739.180000     80.560000       1885.470000
#
#        arr_cancelled  arr_diverted      arr_delay  carrier_delay  \
# count   91653.000000  91653.000000   91653.000000   91653.000000
# mean        6.795271      0.889987    4408.519972    1253.141185
# std        27.862032      4.245160   13404.644997    3327.285102
# min         0.000000      0.000000       0.000000       0.000000
# 25%         0.000000      0.000000     572.000000     202.000000
# 50%         1.000000      0.000000    1401.000000     508.000000
# 75%         5.000000      1.000000    3287.000000    1137.000000
# max      1283.000000    248.000000  356883.000000  134693.000000
#
#        weather_delay      nas_delay  security_delay  late_aircraft_delay  \
# count   91653.000000   91653.000000    91653.000000         91653.000000
# mean      232.490448    1270.455904        7.625162          1644.807273
# std       954.124065    5478.810428       41.204998          5192.477674
# min         0.000000       0.000000        0.000000             0.000000
# 25%         0.000000      79.000000        0.000000            94.000000
# 50%        35.000000     252.000000        0.000000           399.000000
# 75%       180.000000     685.000000        0.000000          1181.000000
# max     57707.000000  130920.000000     3119.000000        145680.000000
#
#        Unnamed: 21
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %% [markdown]
# #### Data Imputation
#
# ##### Checking for invalid entries
#
# We verify no invalid entries our within our dataset. Such entries we may resolve are "NaN," corrupt, or "NA" values.

# %%
df_flights.isnull().sum()
# Out:
# year                       0
# month                      0
# carrier                    0
# carrier_name               0
# airport                    0
# airport_name               0
# arr_flights              184
# arr_del15                214
# carrier_ct               184
# weather_ct               184
# nas_ct                   184
# security_ct              184
# late_aircraft_ct         184
# arr_cancelled            184
# arr_diverted             184
# arr_delay                184
# carrier_delay            184
# weather_delay            184
# nas_delay                184
# security_delay           184
# late_aircraft_delay      184
# Unnamed: 21            91837
# dtype: int64

# %%
df_flights[df_flights['arr_flights'].isnull()== True]
# Out:
#        year  month carrier                 carrier_name airport  \
# 414    2006      1      EV  Atlantic Southeast Airlines     MCI
# 1137   2006      1      TZ       ATA Airlines d/b/a ATA     BWI
# 2337   2006      2      OH                  Comair Inc.     GNV
# 2347   2006      2      OH                  Comair Inc.     ICT
# 2397   2006      2      OH                  Comair Inc.     TRI
# 3425   2006      3      EV  Atlantic Southeast Airlines     ONT
# 5619   2006      4      RU     ExpressJet Airlines Inc.     SBN
# 6797   2006      5      OH                  Comair Inc.     AVL
# 6834   2006      5      OH                  Comair Inc.     FWA
# 6844   2006      5      OH                  Comair Inc.     ICT
# 6886   2006      5      OH                  Comair Inc.     SBN
# 7862   2006      6      EV  Atlantic Southeast Airlines     BOI
# 7949   2006      6      EV  Atlantic Southeast Airlines     OAK
# 8769   2006      6      US              US Airways Inc.     ABI
# 8776   2006      6      US              US Airways Inc.     BGR
# 12347  2006      9      DL         Delta Air Lines Inc.     FAI
# 12924  2006      9      OH                  Comair Inc.     CKB
# 13899  2006     10      DL         Delta Air Lines Inc.     JAC
# 13983  2006     10      EV  Atlantic Southeast Airlines     BZN
# 13991  2006     10      EV  Atlantic Southeast Airlines     CMI
# 14030  2006     10      EV  Atlantic Southeast Airlines     LAN
# 15835  2006     11      NW      Northwest Airlines Inc.     GSP
# 15992  2006     11      OH                  Comair Inc.     TLH
# 15993  2006     11      OH                  Comair Inc.     TOL
# 15994  2006     11      OH                  Comair Inc.     TRI
# 17434  2006     12      OH                  Comair Inc.     FWA
# 17486  2006     12      OH                  Comair Inc.     SHV
# 17489  2006     12      OH                  Comair Inc.     SWF
# 19025  2007      1      OH                  Comair Inc.     AVL
# 19066  2007      1      OH                  Comair Inc.     ICT
# ...     ...    ...     ...                          ...     ...
# 69205  2009      9      NW      Northwest Airlines Inc.     GFK
# 69225  2009      9      NW      Northwest Airlines Inc.     MSO
# 69250  2009      9      NW      Northwest Airlines Inc.     SYR
# 70367  2009     10      EV  Atlantic Southeast Airlines     MKE
# 70427  2009     10      F9       Frontier Airlines Inc.     OKC
# 70692  2009     10      NW      Northwest Airlines Inc.     SAT
# 70809  2009     10      OO        SkyWest Airlines Inc.     FNT
# 70867  2009     10      OO        SkyWest Airlines Inc.     PNS
# 71759  2009     11      EV  Atlantic Southeast Airlines     BTV
# 72176  2009     11      OH                  Comair Inc.     FNT
# 72272  2009     11      OO        SkyWest Airlines Inc.     GSP
# 72285  2009     11      OO        SkyWest Airlines Inc.     JAN
# 72711  2009     11      YV           Mesa Airlines Inc.     ICT
# 73254  2009     12      EV  Atlantic Southeast Airlines     FSD
# 73333  2009     12      F9       Frontier Airlines Inc.     GEG
# 74240  2009     12      YV           Mesa Airlines Inc.     RKS
# 75152  2010      1      OO        SkyWest Airlines Inc.     CLT
# 77125  2010      3      9E       Pinnacle Airlines Inc.     AGS
# 77684  2010      3      F9       Frontier Airlines Inc.     COS
# 80817  2010      5      OH                  Comair Inc.     CAE
# 82370  2010      6      OO        SkyWest Airlines Inc.     AZO
# 82980  2010      7      9E       Pinnacle Airlines Inc.     GPT
# 83050  2010      7      9E       Pinnacle Airlines Inc.     TLH
# 83523  2010      7      F9       Frontier Airlines Inc.     GRB
# 88010  2010     10      F9       Frontier Airlines Inc.     OKC
# 88253  2010     10      OH                  Comair Inc.     CAK
# 88987  2010     11      9E       Pinnacle Airlines Inc.     TRI
# 89710  2010     11      OH                  Comair Inc.     AVP
# 89776  2010     11      OH                  Comair Inc.     SAT
# 90600  2010     12      B6              JetBlue Airways     AVP
#
#                                             airport_name  arr_flights  \
# 414           Kansas City, MO: Kansas City International          NaN
# 1137   Baltimore, MD: Baltimore/Washington Internatio...          NaN
#
#
# The following will remove the ill-entred values:

# %%
df_flights = df_flights[df_flights['arr_flights'].isnull()== False]

# %%
df_flights_col_noUnamed21 = list(df_flights.columns)
df_flights_col_noUnamed21.pop(-1)
# Out:
# 'Unnamed: 21'

# %%
df_flights=df_flights[df_flights_col_noUnamed21]

# %%
df_flights.shape
# Out:
# (91653, 21)

# %% [markdown]
# The above is a confirmation of removing the ill data-filled "Unnamed:21" feature.

# %%
df_flights = df_flights[df_flights['arr_del15'].isnull()== False]

# %%
df_flights.shape
# Out:
# (91623, 21)

# %%
df_flights.isnull().sum()
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64

# %%
df_flights.head(2)
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2006      8      AA  American Airlines Inc.     ABQ
# 1  2006      8      AA  American Airlines Inc.     ANC
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...        310.0       73.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...         62.0       38.0
#
#    carrier_ct  weather_ct         ...           security_ct  late_aircraft_ct  \
# 0       17.53        8.83         ...                   1.0             26.51
# 1       11.53        0.88         ...                   0.0             11.27
#
#    arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0            5.0           1.0     3742.0          838.0          585.0
# 1            0.0           0.0     2605.0          879.0          100.0
#
#    nas_delay  security_delay  late_aircraft_delay
# 0      729.0            21.0               1569.0
# 1      870.0             0.0                756.0
#
# [2 rows x 21 columns]

# %% [markdown]
# We can now confirm the following:
#
# 1. Corrected feature titles
#
# 2. All data entries have been imputed
#
# 3. We have removed the bad feature "Unnamed:21"
#
# #### Selecting Features

# %%
df_flights.dtypes
# Out:
# year                     int64
# month                    int64
# carrier                 object
# carrier_name            object
# airport                 object
# airport_name            object
# arr_flights            float64
# arr_del15              float64
# carrier_ct             float64
# weather_ct             float64
# nas_ct                 float64
# security_ct            float64
# late_aircraft_ct       float64
# arr_cancelled          float64
# arr_diverted           float64
# arr_delay              float64
# carrier_delay          float64
# weather_delay          float64
# nas_delay              float64
# security_delay         float64
# late_aircraft_delay    float64
# dtype: object

# %%
semi_final_feature = list(df_flights.columns)
df_flights_semi_final = df_flights[semi_final_feature ]

# %% [markdown]
# We observe the data types for a majority of the features are correct. However, in hindsight, our Month and Year features are not quite dates. I.e., Two features in our dataset are not of "Date" types.
#
# The following creates a new "Date" feature in our dataset, for time series analysis.
#
# ##### Add Date Feature

# %%
df_flights_semi_final['Date'] = pd.to_datetime(
    dict(year = df_flights_semi_final['year'],
         month = df_flights_semi_final['month'],day =1)
                                    )

# %%
df_flights_semi_final.head(2)
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2006      8      AA  American Airlines Inc.     ABQ
# 1  2006      8      AA  American Airlines Inc.     ANC
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...        310.0       73.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...         62.0       38.0
#
#    carrier_ct  weather_ct    ...      late_aircraft_ct  arr_cancelled  \
# 0       17.53        8.83    ...                 26.51            5.0
# 1       11.53        0.88    ...                 11.27            0.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           1.0     3742.0          838.0          585.0      729.0
# 1           0.0     2605.0          879.0          100.0      870.0
#
#    security_delay  late_aircraft_delay       Date
# 0            21.0               1569.0 2006-08-01
# 1             0.0                756.0 2006-08-01
#
# [2 rows x 22 columns]

# %%
df_flights.columns[6:21]
# Out:
# Index(['arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='object')

# %% [markdown]
# ##### Proportion Statistics
#
# Learning from Patrick Senti's [Flight Data project](https://miraculixx.github.io/flightdelays/index.html) and [feedback](../Images/Feedback/Feedback1.jpg) to us, we create several features that are proportional represenations of the delay features we established above.
#
# I.e., We convert several flight delay features into proportions by month or by year.
#
# For each case, we convert the proportions from their respective metrics, delay by minutes and delay count.
#
# The following table indicates the categories each set of features will be converted to proportional representations:
#
# | Delay by Minutes | Delay Count |
# |---------|-----|
# |arr_delay  | arr_flights  |
# |   carrier_delay      | arr_del15  |
# |         weather_delay                     |   carrier_ct  |
# |nas_delay| weather_ct  |
# |      security_delay      | nas_ct  |
# |                late_aircraft_delay               |   security_ct  |
# |                               |   late_aircraft_ct  |
# |                               |   arr_cancelled  |
# |                               |   arr_diverted  |
#
# The following is a function that takes in an array of selected features with its respected dataset & time type, and outputs a new dataframe with the new features by grouped proportional times. .

# %%
df_flights.head(1)
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2006      8      AA  American Airlines Inc.     ABQ
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...        310.0       73.0
#
#    carrier_ct  weather_ct         ...           security_ct  late_aircraft_ct  \
# 0       17.53        8.83         ...                   1.0             26.51
#
#    arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0            5.0           1.0     3742.0          838.0          585.0
#
#    nas_delay  security_delay  late_aircraft_delay
# 0      729.0            21.0               1569.0
#
# [1 rows x 21 columns]

# %%
'''
Create a summary dataset for delay by minutes and delay counts in their respective proportions, and time
time (year or month) restrictions

Parameters: 
-Data: Dataset
-Seleceted Features: Desired Features
-time_type: Year or Month
'''
import math
def to_proportion(data, selected_features,time_type):
    '''
    Receive a list of the time values in our time_type
    
    E.x. Years is an array 2006,2007,2008,2009,2010
    '''
    time_list = list(data[time_type].unique())
    
    
     #Partition data for delay by minutes metrics and delay count metrics
    selected_features_mins = selected_features[9:] ##6 features
    selected_features_ct = selected_features[:9] ##9 features
    
    '''
    Generated titles for new features, by proportion. 
    These titles are implemented for both "delays by minutes and delays counts"
    
    I.e. Names + proportion_by_timeType== new features

    '''
    selected_feat_names_ct = []
    selected_feat_names_mins = []
    for i in range(0,len(selected_features_ct)):
        selected_feat_names_ct.append("{name}_prop_by_{time}".format(name = selected_features_ct[i], time = time_type))
        
        if i< (len(selected_features_mins)):
            selected_feat_names_mins.append("{name}_prop_by_{time}".format(name = selected_features_mins[i], time = time_type))
   
    ''' Concat the two '{name}_prop_by_{time}' lists'''
    feature_titles = selected_feat_names_mins+selected_feat_names_ct
    
    #Instantiate empty dataframe
    dataset_finished = pd.DataFrame(columns=feature_titles )
    
    #Empty dictionary to store our arrays with "selected_feat_names_{ct/mins}" keys
    dictionary = {}
    dictionary[time_type]=[]
    for i in selected_feat_names_ct:
        dictionary[i] = []
       
    dictionary_2 = {}
    dictionary_2[time_type]=[]
    for i in selected_feat_names_mins:
        dictionary_2[i] = []
        
    #Temporary list for attaining time values with respect to row operation    
    ls_time = []
    
    #Loop through the unique time entries
    for i_time, i_val in enumerate(time_list):
        #Add time values
        ls_time.append(i_val)
        
        #Get sum of delay counts by some time_type
        ds_delay_sum = 0.0
        for i, val in enumerate(selected_features_ct):
            ds_delay_sum += data.groupby(time_type).sum()[val][i_val]
        
        #Get sum of delay by mins by some time_type
        ds_delay_sum_mins = 0.0
        for i, val in enumerate(selected_features_mins):
            ds_delay_sum_mins += data.groupby(time_type).sum()[val][i_val]
        
        #Loop through our selected features for conversion to proportionality
        for i, val in enumerate(selected_features_ct):
            ds_sum = data.groupby(time_type).sum()[val][i_val]
            dictionary[selected_feat_names_ct[i]].append(ds_sum/ds_delay_sum)
            
            #Stop for loop operation at length of selected_features_mins
        for i, val in enumerate(selected_features_mins):
            ds_sum_2 = data.groupby(time_type).sum()[val][i_val]
            dictionary_2[selected_feat_names_mins[i]].append(ds_sum_2/ds_delay_sum_mins)
            
    #Add time information to both dictionaries        
    dictionary[time_type]=ls_time
    dictionary_2[time_type]=ls_time

    #Convert delay by count dictionary information to dataframe summary  
    key_info_ct = list(dictionary.keys())
    key_info_mins = list(dictionary_2.keys())
    for i, val in enumerate(key_info_ct):
        dataset_finished[key_info_ct[i]] = dictionary[key_info_ct[i]]
    
        #Convert delay by minutes dictionary information to dataframe summary     
    for i, val in enumerate(key_info_mins):
        dataset_finished[key_info_mins[i]] = dictionary_2[key_info_mins[i]]
        
        
    return dataset_finished

# %%
last_feat = list(df_flights.columns[6:21])
df_flights_final_proportion_byYear = to_proportion(df_flights_semi_final, last_feat, "year")

# %%
df_flights_final_proportion_byYear
# Out:
#    arr_delay_prop_by_year  carrier_delay_prop_by_year  \
# 0                     0.5                    0.139099
# 1                     0.5                    0.142757
# 2                     0.5                    0.138786
# 3                     0.5                    0.140185
# 4                     0.5                    0.151899
#
#    weather_delay_prop_by_year  nas_delay_prop_by_year  \
# 0                    0.027836                0.146872
# 1                    0.028452                0.139698
# 2                    0.026742                0.151039
# 3                    0.024925                0.153170
# 4                    0.022015                0.128278
#
#    security_delay_prop_by_year  late_aircraft_delay_prop_by_year  \
# 0                     0.001270                          0.184923
# 1                     0.000876                          0.188217
# 2                     0.000660                          0.182773
# 3                     0.000597                          0.181122
# 4                     0.000849                          0.196959
#
#    arr_flights_prop_by_year  arr_del15_prop_by_year  carrier_ct_prop_by_year  \
# 0                  0.679464                0.153698                 0.043555
# 1                  0.663208                0.160479                 0.046310
# 2                  0.686294                0.149281                 0.040298
# 3                  0.717360                0.135490                 0.036005
# 4                  0.722410                0.131587                 0.037977
#
#    weather_ct_prop_by_year  nas_ct_prop_by_year  security_ct_prop_by_year  \
# 0                 0.006330             0.052926                  0.000562
# 1                 0.006432             0.053219                  0.000439
# 2                 0.005545             0.053835                  0.000319
# 3                 0.004656             0.050118                  0.000259
# 4                 0.004016             0.042181                  0.000342
#
#    late_aircraft_ct_prop_by_year  arr_cancelled_prop_by_year  \
# 0                       0.050324                    0.011600
# 1                       0.054079                    0.014305
# 2                       0.049284                    0.013455
# 3                       0.044453                    0.009939
# 4                       0.047070                    0.012684
#
#    arr_diverted_prop_by_year  year
# 0                   0.001540  2006
# 1                   0.001528  2007
# 2                   0.001689  2008
# 3                   0.001720  2009
# 4                   0.001733  2010

# %%
df_flights_final_proportion_byMonth = to_proportion(df_flights_semi_final, last_feat, "month")

# %%
df_flights_final_proportion_byMonth
# Out:
#     arr_delay_prop_by_month  carrier_delay_prop_by_month  \
# 0                       0.5                     0.148793
# 1                       0.5                     0.143305
# 2                       0.5                     0.140318
# 3                       0.5                     0.142012
# 4                       0.5                     0.142434
# 5                       0.5                     0.137454
# 6                       0.5                     0.134920
# 7                       0.5                     0.143582
# 8                       0.5                     0.154819
# 9                       0.5                     0.140305
# 10                      0.5                     0.146730
# 11                      0.5                     0.138342
#
#     weather_delay_prop_by_month  nas_delay_prop_by_month  \
# 0                      0.026149                 0.134675
# 1                      0.029124                 0.146847
# 2                      0.030009                 0.142287
# 3                      0.024047                 0.142180
# 4                      0.022547                 0.149571
# 5                      0.024082                 0.154109
# 6                      0.030736                 0.143087
# 7                      0.029241                 0.133986
# 8                      0.023959                 0.152002
# 9                      0.020753                 0.157576
# 10                     0.018480                 0.155882
# 11                     0.029634                 0.133918
#
#     security_delay_prop_by_month  late_aircraft_delay_prop_by_month  \
# 0                       0.001496                           0.188888
# 1                       0.000949                           0.179776
# 2                       0.000932                           0.186453
# 3                       0.000883                           0.190878
# 4                       0.000971                           0.184477
# 5                       0.000658                           0.183697
# 6                       0.000656                           0.190600
# 7                       0.000755                           0.192436
# 8                       0.000787                           0.168433
# 9                       0.000708                           0.180659
# 10                      0.000623                           0.178285
# 11                      0.000877                           0.197230
#
#     arr_flights_prop_by_month  arr_del15_prop_by_month  \
# 0                    0.695497                 0.146379
# 1                    0.686326                 0.147882
# 2                    0.668378                 0.153652
# 3                    0.683357                 0.150596
# 4                    0.713071                 0.137809
# 5                    0.711393                 0.139707
# 6                    0.656146                 0.164694
# 7                    0.671654                 0.157626
# 8                    0.750028                 0.119693
# 9                    0.715622                 0.137513
# 10                   0.742500                 0.124546
# 11                   0.629464                 0.174160
#
#     carrier_ct_prop_by_month  weather_ct_prop_by_month  nas_ct_prop_by_month  \
# 0                   0.043045                  0.005635              0.046643
# 1                   0.041119                  0.006214              0.052792
# 2                   0.041777                  0.006377              0.053916
# 3                   0.042452                  0.005124              0.051302
# 4                   0.038479                  0.004273              0.049197
# 5                   0.037221                  0.004772              0.051427
# 6                   0.045758                  0.007161              0.054408
# 7                   0.046129                  0.006795              0.049245
# 8                   0.034641                  0.004063              0.044060
# 9                   0.036795                  0.003918              0.051499
# 10                  0.034715                  0.003337              0.046405
# 11                  0.048398                  0.007206              0.056522
#
#     security_ct_prop_by_month  late_aircraft_ct_prop_by_month  \
# 0                    0.000673                        0.050384
# 1                    0.000392                        0.047365
# 2                    0.000411                        0.051172
# 3                    0.000428                        0.051290
# 4                    0.000365                        0.045496
# 5                    0.000289                        0.045998
# 6                    0.000369                        0.056998
# 7                    0.000385                        0.055072
# 8                    0.000261                        0.036668
# 9                    0.000296                        0.045006
# 10                   0.000245                        0.039844
# 11                   0.000514                        0.061520
#
#     arr_cancelled_prop_by_month  arr_diverted_prop_by_month  month
# 0                      0.009897                    0.001848      8
# 1                      0.016334                    0.001577      1
# 2                      0.022740                    0.001577      2
# 3                      0.013946                    0.001505      3
# 4                      0.009882                    0.001429      4
# 5                      0.007680                    0.001513      5
# 6                      0.012212                    0.002253      6
# 7                      0.010982                    0.002111      7
# 8                      0.009245                    0.001340      9
# 9                      0.008094                    0.001257     10
# 10                     0.007244                    0.001163     11
# 11                     0.020395                    0.001821     12

# %% [markdown]
# ###### Percentage Representation
#
# In future visualizations, it is ideal to simply know that these values are represented as percentages.
#
# I.e. We want future readers to avoid the hassel of moving their eyes continously and simultaneously converting decimals to percentage representations.
#
# The following alleviates this concern.

# %%
df_lengthMonth = len(list(df_flights_final_proportion_byMonth.columns))
df_colMonth = list(df_flights_final_proportion_byMonth.columns)[0:df_lengthMonth-1]
df_flights_final_proportion_byMonth[df_colMonth] = df_flights_final_proportion_byMonth[df_colMonth] *100
df_flights_final_proportion_byMonth
# Out:
#     arr_delay_prop_by_month  carrier_delay_prop_by_month  \
# 0                      50.0                    14.879281
# 1                      50.0                    14.330502
# 2                      50.0                    14.031790
# 3                      50.0                    14.201181
# 4                      50.0                    14.243352
# 5                      50.0                    13.745442
# 6                      50.0                    13.492031
# 7                      50.0                    14.358218
# 8                      50.0                    15.481939
# 9                      50.0                    14.030452
# 10                     50.0                    14.673017
# 11                     50.0                    13.834167
#
#     weather_delay_prop_by_month  nas_delay_prop_by_month  \
# 0                      2.614873                13.467461
# 1                      2.912371                14.684660
# 2                      3.000910                14.228718
# 3                      2.404698                14.217984
# 4                      2.254674                14.957127
# 5                      2.408188                15.410867
# 6                      3.073614                14.308748
# 7                      2.924063                13.398624
# 8                      2.395944                15.200161
# 9                      2.075318                15.757558
# 10                     1.848037                15.588230
# 11                     2.963351                13.391796
#
#     security_delay_prop_by_month  late_aircraft_delay_prop_by_month  \
# 0                       0.149616                          18.888770
# 1                       0.094874                          17.977592
# 2                       0.093246                          18.645336
# 3                       0.088325                          19.087811
# 4                       0.097132                          18.447716
# 5                       0.065794                          18.369709
# 6                       0.065613                          19.059995
# 7                       0.075460                          19.243635
# 8                       0.078662                          16.843294
# 9                       0.070814                          18.065858
# 10                      0.062254                          17.828463
# 11                      0.087691                          19.722995
#
#     arr_flights_prop_by_month  arr_del15_prop_by_month  \
# 0                   69.549679                14.637910
# 1                   68.632579                14.788186
# 2                   66.837797                15.365223
# 3                   68.335732                15.059568
# 4                   71.307123                13.780874
# 5                   71.139261                13.970722
# 6                   65.614589                16.469428
# 7                   67.165446                15.762616
# 8                   75.002835                11.969338
# 9                   71.562228                13.751309
# 10                  74.249992                12.454627
# 11                  62.946439                17.416003
#
#     carrier_ct_prop_by_month  weather_ct_prop_by_month  nas_ct_prop_by_month  \
# 0                   4.304487                  0.563460              4.664310
# 1                   4.111925                  0.621391              5.279161
# 2                   4.177687                  0.637688              5.391592
# 3                   4.245204                  0.512411              5.130208
# 4                   3.847896                  0.427250              4.919660
# 5                   3.722125                  0.477161              5.142697
# 6                   4.575815                  0.716081              5.440786
# 7                   4.612866                  0.679494              4.924535
# 8                   3.464078                  0.406269              4.406045
# 9                   3.679541                  0.391813              5.149861
# 10                  3.471486                  0.333677              4.640542
# 11                  4.839768                  0.720561              5.652246
#
#     security_ct_prop_by_month  late_aircraft_ct_prop_by_month  \
# 0                    0.067311                        5.038360
# 1                    0.039239                        4.736468
# 2                    0.041072                        5.117196
# 3                    0.042778                        5.128987
# 4                    0.036456                        4.549632
# 5                    0.028923                        4.599841
# 6                    0.036940                        5.699807
# 7                    0.038503                        5.507229
# 8                    0.026128                        3.666820
# 9                    0.029561                        4.500551
# 10                   0.024547                        3.984407
# 11                   0.051382                        6.152048
#
#     arr_cancelled_prop_by_month  arr_diverted_prop_by_month  month
# 0                      0.989724                    0.184759      8
# 1                      1.633396                    0.157655      1
# 2                      2.274009                    0.157734      2
# 3                      1.394609                    0.150504      3
# 4                      0.988184                    0.142925      4
# 5                      0.767981                    0.151290      5
# 6                      1.221210                    0.225343      6
# 7                      1.098165                    0.211147      7
# 8                      0.924469                    0.134018      9
# 9                      0.809447                    0.125690     10
# 10                     0.724390                    0.116332     11
# 11                     2.039491                    0.182061     12

# %%
df_lengthYear = len(list(df_flights_final_proportion_byYear.columns))
df_colYear = list(df_flights_final_proportion_byYear.columns)[0:df_lengthYear-1]
df_flights_final_proportion_byYear[df_colYear] = df_flights_final_proportion_byYear[df_colYear] *100
df_flights_final_proportion_byYear
# Out:
#    arr_delay_prop_by_year  carrier_delay_prop_by_year  \
# 0                    50.0                   13.909920
# 1                    50.0                   14.275670
# 2                    50.0                   13.878563
# 3                    50.0                   14.018509
# 4                    50.0                   15.189903
#
#    weather_delay_prop_by_year  nas_delay_prop_by_year  \
# 0                    2.783581               14.687226
# 1                    2.845172               13.969826
# 2                    2.674183               15.103940
# 3                    2.492490               15.317048
# 4                    2.201488               12.827822
#
#    security_delay_prop_by_year  late_aircraft_delay_prop_by_year  \
# 0                     0.126952                         18.492322
# 1                     0.087627                         18.821704
# 2                     0.065973                         18.277341
# 3                     0.059711                         18.112242
# 4                     0.084899                         19.695889
#
#    arr_flights_prop_by_year  arr_del15_prop_by_year  carrier_ct_prop_by_year  \
# 0                 67.946369               15.369794                 4.355547
# 1                 66.320811               16.047921                 4.631022
# 2                 68.629390               14.928106                 4.029829
# 3                 71.735997               13.549043                 3.600465
# 4                 72.240991               13.158659                 3.797734
#
#    weather_ct_prop_by_year  nas_ct_prop_by_year  security_ct_prop_by_year  \
# 0                 0.633026             5.292615                  0.056167
# 1                 0.643213             5.321865                  0.043940
# 2                 0.554535             5.383483                  0.031862
# 3                 0.465598             5.011791                  0.025890
# 4                 0.401564             4.218096                  0.034247
#
#    late_aircraft_ct_prop_by_year  arr_cancelled_prop_by_year  \
# 0                       5.032444                    1.160048
# 1                       5.407890                    1.430493
# 2                       4.928411                    1.345516
# 3                       4.445317                    0.993940
# 4                       4.707039                    1.268362
#
#    arr_diverted_prop_by_year  year
# 0                   0.153989  2006
# 1                   0.152844  2007
# 2                   0.168869  2008
# 3                   0.171959  2009
# 4                   0.173308  2010

# %% [markdown]
# ## Export Data

# %% [markdown]
# We partition the "df_flights_semi_final_with_prop" dataset into the following:
#
# 1. **df_flights_final_proportion_byYear:** The flight data in proportion of minutes to total delay minutes in its respective year
#
# 2. **df_flights_final_proportion_byMonth:** The flight data in proportion of minutes to total delay minutes in its respective month

# %%
df_flights_final_proportion_byYear.to_csv('../Data/PreparedData/flight_data_byYear.csv',sep=',', header=True)

df_flights_final_proportion_byMonth.to_csv('../Data/PreparedData/flight_data_byMonth.csv',sep=',', header=True)

# %% [markdown]
# ## Resources
#
#
# 1. [Flight Data](https://www.transtats.bts.gov/OT_Delay/OT_DelayCause1.asp)
#
# 2. [Dimple Basics](http://napitupulu-jon.appspot.com/posts/dimple-ud507.html)
#
# 3. [bz2 import](https://pymotw.com/2/bz2/)
#
# 4. [Data Dictionary](https://www.transtats.bts.gov/Fields.asp)
#
# 5. [Encoding German Codec](https://stackoverflow.com/questions/18197772/python-german-umlaut-issues-ascii-codec-cant-decode-byte-0xe4-in-position-1)
#
# 6. [Faster Data Loading through Sampling](http://nikgrozev.com/2015/06/16/fast-and-simple-sampling-in-pandas-when-loading-data-from-files/)
#
# 7. [Types of Recorded Delays](https://www.rita.dot.gov/bts/help/aviation/html/understanding.html#q4)
#
# 8. [The Great Recession](http://www.investopedia.com/terms/g/great-recession.asp)
#
# 9. [EDA Visualization Design/Planning](http://guides.library.georgetown.edu/datavisualization)
#
# 10. [How to add a Data Viz Legend](https://stackoverflow.com/questions/28739608/completely-custom-legend-in-matplotlib-python)

# %% [markdown]
#  ## Data Dictionary
#
# 1. **year:** Year
#
# 2. **month:** Month
#
# 3. **carrier:** Code assigned by IATA and commonly used to identify a carrier. As the same code may have been assigned to different carriers over time, the code is not always unique. For analysis, use the Unique Carrier Code.
#
# 4. **carrier_name:** Carrier Name
#
# 5. **airport:** Airport Code
#
# 6. **airport_name:** Airport Name
#
# 7. **arr_flights:** Count of flights that arrived on time
#
# 8. **arr_del15:** Count of arrival delays by 15mins or more
#
# 9. **carrier_ct:** Count delays due to carrier
#
# 10. **weather_ct:** Count of delays due to weather
#
# 11. **nas_ct:** Count of delays due to NAS
#
# 12. **security_ct:** Count of delays due to Security
#
# 13. **late_aircraft_ct:** Count of delays due to late aircraft
#
# 14. **arr_cancelled:** Arrivals Cancelled
#
# 15. **arr_diverted:** Arrivals diverted
#
# 16.  **arr_delay:** Difference in minutes between scheduled and actual arrival time. Early arrivals show negative numbers.
#
# 17. **carrier_delay:** Carrier Delay, in Minutes
#
# 18. **weather_delay:** Weather Delay, in Minutes
#
# 19. **nas_delay:** National Aviation System Delay, in Minutes
#
# 20. **security_delay:** Security Delay, in Minutes
#
# 21. **late_aircraft_delay:** Late Aircraft Delay, in Minutes
