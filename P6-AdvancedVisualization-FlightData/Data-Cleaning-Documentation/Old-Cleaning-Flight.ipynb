# %% [markdown]
# # Flight Data Data Cleaning (Legendary)

# %% [markdown]
# NOTE: This documenation is old, and the data export associated with it is old as well. It exists for the sake of producing old information for past versions of my index.html.
#
#
# ## Data Import and Inspection
#
# This is the documentation for the 2006-2010 Flight Dataset. In this document, we generate a new feature, impute ill inputed/converted data values, and finalize data properties and features for data analysis implementation.

# %%
from zipfile import ZipFile as zp
import numpy as np
import pandas as pd
import string

import time

import matplotlib.pyplot as plt

# %% [markdown]
# ## Import

# %%
def get_csv_file(filename):
    t0 = time.time()
    with zp('../Data/RawData/{}.zip'.format(filename)) as flight_zpfl:
        with flight_zpfl.open('{}.csv'.format(filename)) as f_info:
            dataframe =pd.read_csv(f_info,delimiter=',')
    print("Import loading time was {} seconds".format(time.time()-t0))
    return(dataframe)

# %%
df_flights = get_csv_file('783548897_52017_1328_airline_delay_causes')
# Out:
# Import loading time was 1.172903299331665 seconds

# %% [markdown]
# ### Data Inspection
#
# This section observes several attributes of the flight dataset.

# %%
df_flights.shape
# Out:
# (91837, 22)

# %% [markdown]
# This dataset contains 91837 rows and 22 features.

# %%
df_flights.head(2)
# Out:
#    year   month carrier            carrier_name airport  \
# 0  2006       8      AA  American Airlines Inc.     ABQ
# 1  2006       8      AA  American Airlines Inc.     ANC
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...        310.0       73.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...         62.0       38.0
#
#    carrier_ct   weather_ct     ...       late_aircraft_ct  arr_cancelled  \
# 0       17.53         8.83     ...                  26.51            5.0
# 1       11.53         0.88     ...                  11.27            0.0
#
#    arr_diverted   arr_delay   carrier_delay  weather_delay  nas_delay  \
# 0           1.0      3742.0           838.0          585.0      729.0
# 1           0.0      2605.0           879.0          100.0      870.0
#
#    security_delay  late_aircraft_delay  Unnamed: 21
# 0            21.0               1569.0          NaN
# 1             0.0                756.0          NaN
#
# [2 rows x 22 columns]

# %% [markdown]
# We observe a random space " " in two feature titles (e.g. " month"). The following checks if some space exists in a feature title, and removes it.

# %%
col_names = list(df_flights.columns)
col_names_new =[]
for i in col_names:
    col_names_new.append(i.strip(" "))

# %%
print(col_names_new)
# Out:
# ['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name', 'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct', 'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted', 'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay', 'Unnamed: 21']

# %%
df_flights.columns = col_names_new

# %% [markdown]
# The above list confirms corrections of existing whitespace in feature titles. We now replace this list of corrected titles to the old flight dataframe's title.

# %%
df_flights.dtypes
# Out:
# year                     int64
# month                    int64
# carrier                 object
# carrier_name            object
# airport                 object
# airport_name            object
# arr_flights            float64
# arr_del15              float64
# carrier_ct             float64
# weather_ct             float64
# nas_ct                 float64
# security_ct            float64
# late_aircraft_ct       float64
# arr_cancelled          float64
# arr_diverted           float64
# arr_delay              float64
# carrier_delay          float64
# weather_delay          float64
# nas_delay              float64
# security_delay         float64
# late_aircraft_delay    float64
# Unnamed: 21            float64
# dtype: object

# %% [markdown]
# Lastly, we provide some descriptive statistics for the "df_flights" dataset.

# %%
df_flights.describe()
# Out:
#                year         month   arr_flights     arr_del15    carrier_ct  \
# count  91837.000000  91837.000000  91653.000000  91623.000000  91653.000000
# mean    2007.968847      6.492198    376.501675     80.083298     22.397971
# std        1.399134      3.445474   1008.399764    221.292022     49.784500
# min     2006.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2007.000000      4.000000     62.000000     12.000000      4.320000
# 50%     2008.000000      6.000000    125.000000     28.000000     10.000000
# 75%     2009.000000      9.000000    269.000000     62.000000     21.710000
# max     2010.000000     12.000000  15993.000000   4966.000000   1792.070000
#
#          weather_ct        nas_ct   security_ct  late_aircraft_ct  \
# count  91653.000000  91653.000000  91653.000000      91653.000000
# mean       2.980848     27.622592      0.212576         26.843168
# std       11.647614     98.159085      1.026079         82.746186
# min        0.000000      0.000000      0.000000          0.000000
# 25%        0.000000      2.290000      0.000000          1.960000
# 50%        0.810000      6.870000      0.000000          6.790000
# 75%        2.390000     17.510000      0.000000         18.670000
# max      641.540000   2739.180000     80.560000       1885.470000
#
#        arr_cancelled  arr_diverted      arr_delay  carrier_delay  \
# count   91653.000000  91653.000000   91653.000000   91653.000000
# mean        6.795271      0.889987    4408.519972    1253.141185
# std        27.862032      4.245160   13404.644997    3327.285102
# min         0.000000      0.000000       0.000000       0.000000
# 25%         0.000000      0.000000     572.000000     202.000000
# 50%         1.000000      0.000000    1401.000000     508.000000
# 75%         5.000000      1.000000    3287.000000    1137.000000
# max      1283.000000    248.000000  356883.000000  134693.000000
#
#        weather_delay      nas_delay  security_delay  late_aircraft_delay  \
# count   91653.000000   91653.000000    91653.000000         91653.000000
# mean      232.490448    1270.455904        7.625162          1644.807273
# std       954.124065    5478.810428       41.204998          5192.477674
# min         0.000000       0.000000        0.000000             0.000000
# 25%         0.000000      79.000000        0.000000            94.000000
# 50%        35.000000     252.000000        0.000000           399.000000
# 75%       180.000000     685.000000        0.000000          1181.000000
# max     57707.000000  130920.000000     3119.000000        145680.000000
#
#        Unnamed: 21
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %% [markdown]
# ## Data Imputation
#
# ### Checking for invalid entries
# We verify no invalid entries our within our dataset. Such entries we may resolve are "NaN," corrupt, or "NA" values.

# %%
df_flights.isnull().sum()
# Out:
# year                       0
# month                      0
# carrier                    0
# carrier_name               0
# airport                    0
# airport_name               0
# arr_flights              184
# arr_del15                214
# carrier_ct               184
# weather_ct               184
# nas_ct                   184
# security_ct              184
# late_aircraft_ct         184
# arr_cancelled            184
# arr_diverted             184
# arr_delay                184
# carrier_delay            184
# weather_delay            184
# nas_delay                184
# security_delay           184
# late_aircraft_delay      184
# Unnamed: 21            91837
# dtype: int64

# %%
df_flights[df_flights['arr_flights'].isnull()== True]
# Out:
#        year  month carrier                 carrier_name airport  \
# 414    2006      1      EV  Atlantic Southeast Airlines     MCI
# 1137   2006      1      TZ       ATA Airlines d/b/a ATA     BWI
# 2337   2006      2      OH                  Comair Inc.     GNV
# 2347   2006      2      OH                  Comair Inc.     ICT
# 2397   2006      2      OH                  Comair Inc.     TRI
# 3425   2006      3      EV  Atlantic Southeast Airlines     ONT
# 5619   2006      4      RU     ExpressJet Airlines Inc.     SBN
# 6797   2006      5      OH                  Comair Inc.     AVL
# 6834   2006      5      OH                  Comair Inc.     FWA
# 6844   2006      5      OH                  Comair Inc.     ICT
# 6886   2006      5      OH                  Comair Inc.     SBN
# 7862   2006      6      EV  Atlantic Southeast Airlines     BOI
# 7949   2006      6      EV  Atlantic Southeast Airlines     OAK
# 8769   2006      6      US              US Airways Inc.     ABI
# 8776   2006      6      US              US Airways Inc.     BGR
# 12347  2006      9      DL         Delta Air Lines Inc.     FAI
# 12924  2006      9      OH                  Comair Inc.     CKB
# 13899  2006     10      DL         Delta Air Lines Inc.     JAC
# 13983  2006     10      EV  Atlantic Southeast Airlines     BZN
# 13991  2006     10      EV  Atlantic Southeast Airlines     CMI
# 14030  2006     10      EV  Atlantic Southeast Airlines     LAN
# 15835  2006     11      NW      Northwest Airlines Inc.     GSP
# 15992  2006     11      OH                  Comair Inc.     TLH
# 15993  2006     11      OH                  Comair Inc.     TOL
# 15994  2006     11      OH                  Comair Inc.     TRI
# 17434  2006     12      OH                  Comair Inc.     FWA
# 17486  2006     12      OH                  Comair Inc.     SHV
# 17489  2006     12      OH                  Comair Inc.     SWF
# 19025  2007      1      OH                  Comair Inc.     AVL
# 19066  2007      1      OH                  Comair Inc.     ICT
# ...     ...    ...     ...                          ...     ...
# 69205  2009      9      NW      Northwest Airlines Inc.     GFK
# 69225  2009      9      NW      Northwest Airlines Inc.     MSO
# 69250  2009      9      NW      Northwest Airlines Inc.     SYR
# 70367  2009     10      EV  Atlantic Southeast Airlines     MKE
# 70427  2009     10      F9       Frontier Airlines Inc.     OKC
# 70692  2009     10      NW      Northwest Airlines Inc.     SAT
# 70809  2009     10      OO        SkyWest Airlines Inc.     FNT
# 70867  2009     10      OO        SkyWest Airlines Inc.     PNS
# 71759  2009     11      EV  Atlantic Southeast Airlines     BTV
# 72176  2009     11      OH                  Comair Inc.     FNT
# 72272  2009     11      OO        SkyWest Airlines Inc.     GSP
# 72285  2009     11      OO        SkyWest Airlines Inc.     JAN
# 72711  2009     11      YV           Mesa Airlines Inc.     ICT
# 73254  2009     12      EV  Atlantic Southeast Airlines     FSD
# 73333  2009     12      F9       Frontier Airlines Inc.     GEG
# 74240  2009     12      YV           Mesa Airlines Inc.     RKS
# 75152  2010      1      OO        SkyWest Airlines Inc.     CLT
# 77125  2010      3      9E       Pinnacle Airlines Inc.     AGS
# 77684  2010      3      F9       Frontier Airlines Inc.     COS
# 80817  2010      5      OH                  Comair Inc.     CAE
# 82370  2010      6      OO        SkyWest Airlines Inc.     AZO
# 82980  2010      7      9E       Pinnacle Airlines Inc.     GPT
# 83050  2010      7      9E       Pinnacle Airlines Inc.     TLH
# 83523  2010      7      F9       Frontier Airlines Inc.     GRB
# 88010  2010     10      F9       Frontier Airlines Inc.     OKC
# 88253  2010     10      OH                  Comair Inc.     CAK
# 88987  2010     11      9E       Pinnacle Airlines Inc.     TRI
# 80817                Columbia, SC: Columbia Metropolitan          NaN
# 82370  Kalamazoo, MI: Kalamazoo/Battle Creek Internat...          NaN
# 82980  Gulfport/Biloxi, MS: Gulfport-Biloxi Internati...          NaN
# 83050         Tallahassee, FL: Tallahassee International          NaN
# 83523  Green Bay, WI: Green Bay Austin Straubel Inter...          NaN
# 88010               Oklahoma City, OK: Will Rogers World          NaN
# 88253                   Akron, OH: Akron-Canton Regional          NaN
# 88987  Bristol/Johnson City/Kingsport, TN: Tri-Cities...          NaN
# 89710  Scranton/Wilkes-Barre, PA: Wilkes Barre Scrant...          NaN
# 89776         San Antonio, TX: San Antonio International          NaN
# 90600  Scranton/Wilkes-Barre, PA: Wilkes Barre Scrant...          NaN
#
#        arr_del15  carrier_ct  weather_ct     ...       late_aircraft_ct  \
# 414          NaN         NaN         NaN     ...                    NaN
# 1137         NaN         NaN         NaN     ...                    NaN
# 2337         NaN         NaN         NaN     ...                    NaN
# 2347         NaN         NaN         NaN     ...                    NaN
# 2397         NaN         NaN         NaN     ...                    NaN
# 3425         NaN         NaN         NaN     ...                    NaN
# 5619         NaN         NaN         NaN     ...                    NaN
# 6797         NaN         NaN         NaN     ...                    NaN
# 6834         NaN         NaN         NaN     ...                    NaN
# 6844         NaN         NaN         NaN     ...                    NaN
# 6886         NaN         NaN         NaN     ...                    NaN
# 7862         NaN         NaN         NaN     ...                    NaN
# 7949         NaN         NaN         NaN     ...                    NaN
# 8769         NaN         NaN         NaN     ...                    NaN
# 8776         NaN         NaN         NaN     ...                    NaN
# 12347        NaN         NaN         NaN     ...                    NaN
# 12924        NaN         NaN         NaN     ...                    NaN
# 13899        NaN         NaN         NaN     ...                    NaN
# 13983        NaN         NaN         NaN     ...                    NaN
# 13991        NaN         NaN         NaN     ...                    NaN
# 14030        NaN         NaN         NaN     ...                    NaN
# 15835        NaN         NaN         NaN     ...                    NaN
# 15992        NaN         NaN         NaN     ...                    NaN
# 15993        NaN         NaN         NaN     ...                    NaN
# 15994        NaN         NaN         NaN     ...                    NaN
# 17434        NaN         NaN         NaN     ...                    NaN
# 17486        NaN         NaN         NaN     ...                    NaN
# 17489        NaN         NaN         NaN     ...                    NaN
# 19025        NaN         NaN         NaN     ...                    NaN
# 19066        NaN         NaN         NaN     ...                    NaN
# ...          ...         ...         ...     ...                    ...
# 69205        NaN         NaN         NaN     ...                    NaN
# 69225        NaN         NaN         NaN     ...                    NaN
# 69250        NaN         NaN         NaN     ...                    NaN
# 70367        NaN         NaN         NaN     ...                    NaN
# 70427        NaN         NaN         NaN     ...                    NaN
# 70692        NaN         NaN         NaN     ...                    NaN
# 70809        NaN         NaN         NaN     ...                    NaN
# 70867        NaN         NaN         NaN     ...                    NaN
# 71759        NaN         NaN         NaN     ...                    NaN
# 72176        NaN         NaN         NaN     ...                    NaN
# 72272        NaN         NaN         NaN     ...                    NaN
# 72285        NaN         NaN         NaN     ...                    NaN
# 72711        NaN         NaN         NaN     ...                    NaN
# 75152        NaN             NaN                  NaN          NaN
# 77125        NaN             NaN                  NaN          NaN
# 77684        NaN             NaN                  NaN          NaN
# 80817        NaN             NaN                  NaN          NaN
# 82370        NaN             NaN                  NaN          NaN
# 82980        NaN             NaN                  NaN          NaN
# 83050        NaN             NaN                  NaN          NaN
# 83523        NaN             NaN                  NaN          NaN
# 88010        NaN             NaN                  NaN          NaN
# 88253        NaN             NaN                  NaN          NaN
# 88987        NaN             NaN                  NaN          NaN
# 89710        NaN             NaN                  NaN          NaN
# 89776        NaN             NaN                  NaN          NaN
# 90600        NaN             NaN                  NaN          NaN
#
# [184 rows x 22 columns]

# %% [markdown]
# We observe that from the arr_flights column to the late_aircraft_delay column, there are ~146 ill entries, per column. Moreover, we observe 59112 bad entries in Unnamed:21.
#
# Because of the $\dfrac{184}{\text{Dataset Size}}=\dfrac{184}{91837}=.200\%$ missing entries per column, we can proceed with removing them, without affecting future analyses.
#
# Even more, we have to removed the entire "Unnamed:21" column. With the lack of existence of entries in this column, we can simply disregard/delete it.
#
#
# The following will remove the ill-entred values:

# %%
df_flights = df_flights[df_flights['arr_flights'].isnull()== False]

# %%
df_flights_col_noUnamed21 = list(df_flights.columns)
df_flights_col_noUnamed21.pop(-1)
# Out:
# 'Unnamed: 21'

# %%
df_flights=df_flights[df_flights_col_noUnamed21]

# %%
df_flights.shape
# Out:
# (91653, 21)

# %%
df_flights = df_flights[df_flights['arr_del15'].isnull()== False]

# %%
df_flights.shape
# Out:
# (91623, 21)

# %% [markdown]
# The above is a confirmation of removing the ill data-filled "Unnamed:21" feature.

# %%
df_flights.isnull().sum()
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64

# %%
df_flights.head(2)
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2006      8      AA  American Airlines Inc.     ABQ
# 1  2006      8      AA  American Airlines Inc.     ANC
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...        310.0       73.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...         62.0       38.0
#
#    carrier_ct  weather_ct         ...           security_ct  late_aircraft_ct  \
# 0       17.53        8.83         ...                   1.0             26.51
# 1       11.53        0.88         ...                   0.0             11.27
#
#    arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0            5.0           1.0     3742.0          838.0          585.0
# 1            0.0           0.0     2605.0          879.0          100.0
#
#    nas_delay  security_delay  late_aircraft_delay
# 0      729.0            21.0               1569.0
# 1      870.0             0.0                756.0
#
# [2 rows x 21 columns]

# %% [markdown]
# We can now confirm the following:
#
# 1. Corrected feature titles
#
# 2. All data entries have been imputed
#
# 3. We have removed the bad feature "Unnamed:21"
#
# ### Selecting Features

# %%
df_flights.dtypes
# Out:
# year                     int64
# month                    int64
# carrier                 object
# carrier_name            object
# airport                 object
# airport_name            object
# arr_flights            float64
# arr_del15              float64
# carrier_ct             float64
# weather_ct             float64
# nas_ct                 float64
# security_ct            float64
# late_aircraft_ct       float64
# arr_cancelled          float64
# arr_diverted           float64
# arr_delay              float64
# carrier_delay          float64
# weather_delay          float64
# nas_delay              float64
# security_delay         float64
# late_aircraft_delay    float64
# dtype: object

# %%
semi_final_feature = [ 'year', 'month', 'carrier', 'carrier_name',
                 'airport', 'airport_name','arr_flights','arr_cancelled', 
                 'arr_delay', 'carrier_delay', 'weather_delay', 
                 'nas_delay', 'security_delay',
                 'late_aircraft_delay']
df_flights_semi_final = df_flights[semi_final_feature ]

# %% [markdown]
# We observe the data types for a majority of the features are correct. However, in hindsight, our Month and Year features are not quite dates. I.e., Two features in our dataset are not of "Date" types.
#
# The following creates a new "Date" feature in our dataset, for time series analysis.
#
# ### Add Date Feature

# %%
df_flights_semi_final['Date'] = pd.to_datetime(
    dict(year = df_flights_semi_final['year'],
         month = df_flights_semi_final['month'],day =1)
                                    )
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
df_flights_semi_final.head(2)
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2006      8      AA  American Airlines Inc.     ABQ
# 1  2006      8      AA  American Airlines Inc.     ANC
#
#                                         airport_name  arr_flights  \
# 0  Albuquerque, NM: Albuquerque International Sun...        310.0
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...         62.0
#
#    arr_cancelled  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0            5.0     3742.0          838.0          585.0      729.0
# 1            0.0     2605.0          879.0          100.0      870.0
#
#    security_delay  late_aircraft_delay       Date
# 0            21.0               1569.0 2006-08-01
# 1             0.0                756.0 2006-08-01

# %% [markdown]
# ### Add Proportion Representation of Selected Features
#
# Learning from Patrick Senti's [Flight Data project](https://miraculixx.github.io/flightdelays/index.html) and feedback to us, we create several features that are proportional represenations of the delay features we established above.
#
# I.e., We convert several flight delay features into proportions by month or by year.
#
# The following is a function that takes in an array of selected features with its respected dataset & time type, and outputs a new dataframe with the new features by grouped proportional times. .

# %%
'''
converts a given set of columns into proportions by some time (year or month) for the flight dataset above
'''
def to_proportion(data, selected_features,time_type):
    #Make a copy of original dataframe
    dataset_new = pd.DataFrame(data)

    #Partition data for delay by minutes metrics and delay count metrics
    selected_features_mins = selected_features[:] ##6 features
    selected_features_ct = selected_features[:15] ##15 features
    
    
    '''
    Generated titles for new features, by proportion
    
    I.e. Names + proportion_by_timeType== new features
    '''
    
    selected_feat_names = []
    for i in range(0,len(selected_features)):
        selected_feat_names.append("{name}_prop_by_{time}".format(name = selected_features[i], time = time_type))
    
    '''
    Receive a list of the time values in our time_type
    
    E.x. Years is an array 2006,2007,2008,2009,2010
    '''
    time_list = list(dataset_new[time_type].unique())
    
    
    
    #Empty dictionary to store our arrays with "selected_feat_names" keys
    dictionary = {}
    for i in selected_feat_names:
        dictionary[i] = []
        
    '''
    This remaining portion considers the selected features, list of type of times, 
    and converts features to proportions with respect to some time(year or month)
    '''    
    '''
    get features....loop features....group datasum...loop data'''
    
    #Loop through our selected features
    for i, val in enumerate(selected_features):
        
        #Loop through the unique time entries
        for i_time, i_val in enumerate(time_list):
            
            #Get sum of values for some time i_val in time_list and considered column val
            temp_ds_sum = dataset_new.groupby(time_type).sum()[val][i_val]
            
            #loop through dataset
            for i_ds, row_ds in dataset_new.iterrows():
                
                #If the row's time is equal to time we are considering, then convert to proportion
                #with respect to time i_val
                if row_ds[time_type] == i_val:
                    dictionary[selected_feat_names[i]].append(row_ds[val]/temp_ds_sum)
        
        
        #Add lists from dictionary to dataframe            
        dataset_new[selected_feat_names[i]] = dictionary[selected_feat_names[i]]
    
    return dataset_new

# %%
df_flights.columns[6:21]
# Out:
# Index(['arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='object')

# %%
last_feat = [ 'arr_flights', 'arr_cancelled',
       'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
       'security_delay', 'late_aircraft_delay']
df_flights_semi_final_with_prop = to_proportion(df_flights_semi_final, last_feat, "year")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-91b95bd8d601> in <module>()
#       3        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#       4        'security_delay', 'late_aircraft_delay']
# ----> 5 df_flights_semi_final_with_prop = to_proportion(df_flights_semi_final, last_feat, "year")
#
# <ipython-input-57-ada6cee32526> in to_proportion(data, selected_features, time_type)
#      52
#      53             #loop through dataset
# ---> 54             for i_ds, row_ds in dataset_new.iterrows():
#      55
#      56                 #If the row's time is equal to time we are considering, then convert to proportion
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in iterrows(self)
#     706         klass = self._constructor_sliced
#     707         for k, v in zip(self.index, self.values):
# --> 708             s = klass(v, index=columns, name=k)
#     709             yield k, s
#     710
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     246             else:
#     247                 data = _sanitize_array(data, index, dtype, copy,
# --> 248                                        raise_cast_failure=True)
#     249
#     250                 data = SingleBlockManager(data, index, fastpath=True)
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2950             subarr = _sanitize_index(data, index, copy=True)
#    2951         else:
# -> 2952             subarr = _try_cast(data, True)
#    2953
#    2954         if copy:
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in _try_cast(arr, take_fast_path)
#    2917
#    2918         try:
# -> 2919             subarr = maybe_cast_to_datetime(arr, dtype)
#    2920             if not is_extension_type(subarr):
#    2921                 subarr = np.array(subarr, dtype=dtype, copy=copy)
#
# C:\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in maybe_cast_to_datetime(value, dtype, errors)
#     974         elif not (is_array and not (issubclass(value.dtype.type, np.integer) or
#     975                                     value.dtype == np.object_)):
# --> 976             value = maybe_infer_to_datetimelike(value)
#     977
#     978     return value
#
# C:\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in maybe_infer_to_datetimelike(value, convert_dates)
#     787     """
#     788
# --> 789     if isinstance(value, (ABCDatetimeIndex, ABCPeriodIndex)):
#     790         return value
#     791     elif isinstance(value, ABCSeries):
#
# C:\Anaconda3\lib\site-packages\pandas\core\dtypes\generic.py in _check(cls, inst)
#       7     @classmethod
#       8     def _check(cls, inst):
# ----> 9         return getattr(inst, attr, '_typ') in comp
#      10
#      11     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %%
df_flights_semi_final_with_both_prop = to_proportion(df_flights_semi_final_with_prop, last_feat, "month")

# %%
df_flights_semi_final_with_both_prop.head(1)

# %% [markdown]
# ## Export Data
#
# We partition the "df_flights_semi_final_with_prop" dataset into the following:
#
# 1. df_flights_final: The flight data in minutes
#
# 2. df_flights_final_proportion_byYear: The flight data in proportion of minutes to total delay minutes in its respective year
#
# 3. df_flights_final_proportion_byMonth: The flight data in proportion of minutes to total delay minutes in its respective month
#
# ### Flight Data (in minutes)

# %%
final_feat = [ 'year','month','carrier','carrier_name','airport','airport_name','arr_flights','arr_cancelled', 
                 'arr_delay', 'carrier_delay', 'weather_delay', 
                 'nas_delay', 'security_delay',
                 'late_aircraft_delay','Date']
df_flights_final = df_flights_semi_final_with_both_prop[final_feat]

# %% [markdown]
# ### Flight Data (Proportion by Years)

# %%
final_featuresProportion_byYear = [ 'year','month','carrier','carrier_name','airport','airport_name',
                                    'arr_flights_prop_by_year','arr_cancelled_prop_by_year', 'arr_delay_prop_by_year', 
                                   'carrier_delay_prop_by_year', 'weather_delay_prop_by_year', 'nas_delay_prop_by_year', 
                                   'security_delay_prop_by_year','late_aircraft_delay_prop_by_year','Date']
df_flights_final_proportion_byYear = df_flights_semi_final_with_both_prop[final_featuresProportion_byYear]

# %% [markdown]
# ### Flight Data (proportion by Months)

# %%
final_featuresProportion_byMonth = ['year','month','carrier','carrier_name','airport','airport_name', 
                                    'arr_flights_prop_by_month','arr_cancelled_prop_by_month', 'arr_delay_prop_by_month', 
                                    'carrier_delay_prop_by_month', 'weather_delay_prop_by_month', 'nas_delay_prop_by_month', 
                                    'security_delay_prop_by_month','late_aircraft_delay_prop_by_month']
df_flights_final_proportion_byMonth = df_flights_semi_final_with_both_prop[final_featuresProportion_byMonth]

# %% [markdown]
# ### Export CSV Data

# %%
df_flights_final.to_csv('../Data/PreparedData/flight_data_OLD.csv',sep=',', header=True)

df_flights_final_proportion_byYear.to_csv('../Data/PreparedData/flight_data_byYear_OLD.csv',sep=',', header=True)

df_flights_final_proportion_byMonth.to_csv('../Data/PreparedData/flight_data_byMonth_OLD.csv',sep=',', header=True)

# %% [markdown]
# ## Data Dictionary
#
# 1. Year: 2006-2010
#
# 2. Month: 1-12
#
# 3. DayofMonth: 1-31
#
# 4. DayOfWeek: 1 (Monday) - 7 (Sunday)
#
# 5. DepTime: actual departure time (local, hhmm)
#
# 6. CRSDepTime: scheduled departure time (local, hhmm)
#
# 7. ArrTime: actual arrival time (local, hhmm)
#
# 8. CRSArrTime: scheduled arrival time (local, hhmm)
#
# 9. UniqueCarrier: unique carrier code
#
# 10. FlightNum: flight number
#
# 11. TailNum: plane tail number
#
# 12. ActualElapsedTime: in minutes
#
# 13. CRSElapsedTime: in minutes
#
# 14. AirTime: in minutes
#
# 15. ArrDelay: arrival delay, in minutes
#
# 16. DepDelay: departure delay, in minutes
#
# 17. Origin: origin IATA airport code
#
# 18. Dest: destination IATA airport code
#
# 19. Distance in miles
#
# 20. axiIn: taxi in time, in minutes
#
# 21. TaxiOut: taxi out time in minutes
#
# 22. Cancelled: was the flight cancelled?
#
# 23. CancellationCode:reason for cancellation (A = carrier, B = weather, C = NAS, D = security)
#
# 24. Diverted: 1 = yes, 0 = no
#
# 25. CarrierDelay: in minutes
#
# 26. WeatherDelay: in minutes
#
# 27. NASDelay: in minutes
#
# 28. SecurityDelay: in minutes
#
# 29. LateAircraftDelay: in minutes
